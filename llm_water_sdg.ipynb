# %%
from sympy.physics.units import years
! pip install langchain_community pandas huggingface_hub chromadb==0.4.14 langchain-huggingface
# Out:
# Requirement already satisfied: langchain_community in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (0.3.27)
# Requirement already satisfied: pandas in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: huggingface_hub in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (0.34.3)
# Requirement already satisfied: chromadb==0.4.14 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (0.4.14)
# Requirement already satisfied: langchain-huggingface in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (0.3.1)
# Requirement already satisfied: requests>=2.28 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (2.32.4)
# Requirement already satisfied: pydantic>=1.9 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (2.11.7)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (0.116.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.14) (0.35.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (4.14.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (3.8.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (1.22.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (0.21.4)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (0.16.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from chromadb==0.4.14) (2.3.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (2.0.42)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (0.4.12)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from huggingface_hub) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.4.14) (0.47.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langsmith>=0.1.125->langchain_community) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.14) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.14) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.14) (6.31.1)
# Requirement already satisfied: sympy in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.14) (1.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.14) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.14) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.14) (1.9.0)
# Requirement already satisfied: certifi in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pulsar-client>=3.1.0->chromadb==0.4.14) (2025.8.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pydantic>=1.9->chromadb==0.4.14) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pydantic>=1.9->chromadb==0.4.14) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pydantic>=1.9->chromadb==0.4.14) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from requests>=2.28->chromadb==0.4.14) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from requests>=2.28->chromadb==0.4.14) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from requests>=2.28->chromadb==0.4.14) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: colorama in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from tqdm>=4.65.0->chromadb==0.4.14) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.4.14) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.4.14) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.4.14) (14.1.0)
# Requirement already satisfied: h11>=0.8 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.14) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.14) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.14) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.14) (15.0.1)
# Requirement already satisfied: anyio in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.14) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.14) (2.19.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.14) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.14) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: pyreadline3 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.14) (3.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mediamonster\desktop\master\ma2\ai_ma2\pjt_ai_water_ngos\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.4.14) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#load pdf documents from the specified path
from langchain.document_loaders import PyPDFLoader
import os


def load_pdfs_from_path(pdf_dir="data/pdf"):
    pdf_docs = []
    for filename in os.listdir(pdf_dir):
        if filename.endswith(".pdf"):
            file_path = os.path.join(pdf_dir, filename)
            loader = PyPDFLoader(file_path)
            pdf_docs.append(loader.load())
    return pdf_docs


pdf_documents = load_pdfs_from_path()
pdf_documents
# Out:
# [[Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 0, 'page_label': '1'}, page_content='|  \n                     1'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 1, 'page_label': '2'}, page_content='2                 \n   |  \n  \n \n \n \n \n \nDisclaimer \nThe material in this report is of a general nature and should not be regarded as legal advice or relied on for assistance in any \nparticular circumstance or emergency situation. In any important matter, you should seek appropriate independent \nprofessional advice in relation to your own circumstances. The Australian National University and the Global Water Monitor \nConsortium partners accept no responsibility or liability for any damage, loss or expense incurred as a result of reliance on  the \ninformation contained in this report.  \n \n \n \n \n \n \n \n \nHow to cite:  \nVan Dijk, A.I.J.M., H.E. Beck, E. Boergens, R.A.M. de Jeu, W.A. Dorigo, C. Edirisinghe, E. Forootan, E. Guo, A. Güntner, J. Hou, N. \nMehrnegar, S. Mo, W. Preimesberger, J. Rahman, P. Rozas Larraondo (202 5) Global Water Monitor 2024, Summary Report. \nPublished by Global Water Monitor Consortium, available at www.globalwater.online  \n \n  \n \n© Australian National University, 2025 \nThe CC BY licence is a standard form licence agreement that allows you to copy and redistribute the material in any medium \nor format, as well as remix, transform, and build upon the material, on the condition that you provide a link to the licence,  you \nindicate if changes were made, and you attribute the material as follows: Licensed by the Global Water Monitor Consortium \nunder a Creative Commons Attribution 4.0 International licence.  \n \n \nFront cover image: Sentinel-2 satellite image of part of Lake Chad in Western Africa in November 2024, having filled after an unusually wet \nmonsoon season.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 2, 'page_label': '3'}, page_content="|  \n                     3 \n \nOur global water systems are under mounting pressure as climate change drives more extreme weather events and \ndisrupts the water cycle. The year 2024 was a year of extremes but not an isolated occurrence. It fits with a worsening \ntrend of more intense floods, prolonged droughts, and record-breaking extremes. These changes impact water \navailability and increase the risks to lives, infrastructure and ecosystems from water-related disasters. \nReliable and timely information about water resources and hazards is more crucial than ever, yet traditional ground-\nbased measurement networks continue to decline. Satellite observations now play a vital role, offering rapid and \nconsistent global data on the atmosphere and Earth's surface, but they should not replace networks on the ground. \nThe Global Water Monitor Consortium unites public and private organisations to deliver open, actionable climate and \nwater data. By integrating satellite and ground observations, we aim to provide timely updates on critical aspects of the \nwater cycle. Our Global Water Monitor platform (www.globalwater.online) allows anyone to explore a wealth of climate \nand water data free of charge. \nThis third annual report builds on the work of previous years, summarising the state of the global water cycle in 2024, \nidentifying key trends, and analysing major hydrological events. It includes updated metrics on rainfall, temperature, air \nhumidity, river flows and water stored in lakes, soil and underground. It also provides insights into extreme rainfall and \ntemperatures. \nThis report reinforces a clear message: as the planet warms, water challenges are escalating, year after year. By trying \nto provide information on changes and events, we hope to support informed decision-making to protect communities, \ninfrastructure, and ecosystems in an increasingly volatile future \n2 January 2025 \n \nAlbert van Dijk \nProfessor of Water Science and Management, Australian National University \nChair, Global Water Monitor Consortium"),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 3, 'page_label': '4'}, page_content='4                 \n   |  \n  \n \n \nAbout this report \nThe Global Water Monitor provides free, rapid, global information on climate and water resources. This summary report \ncontains information on rainfall, air temperature, humidity, soil and groundwater conditions, vegetation condition, river \nflows, flooding, and lake volumes in 2024. Trends in the water cycle and some of the most important hydrological \nevents of 2024 are interpreted and discussed. \nGlobal summary \nKey aspects of the water cycle in 2024 over the global land area were: \n• Precipitation over land was close to the 1995–2005 average. Extremely dry months have become increasingly \ncommon in recent decades, with 38% more record-dry months in 2024 than for the baseline period. \n• Daily precipitation extremes were 52% more common in 2024 than during 1995–2005, with record-breaking \ndaily rainfall events in West Africa, Europe and Asia. There has been a significant increasing trend of 4% per \ndecade over land. \n• Average temperature over land was the highest recorded globally and in 111 countries, and globally 1.2°C \nabove the 1995–2005 average. The frequency of record-warm months was the highest since 1979. \n• High temperature: new records were set for annual maximum temperature in 34 countries and hot days in 40 \ncountries. Both show increasing trends. \n• Low temperatures: globally, the number of frost days over land was the lowest on record. Annual minimum \ntemperatures are increasing, especially in the tropics. \n• Relative air humidity over land was the highest since 2018, but a declining trend remains. Humidity was very \nlow in South America and Central Africa in 2024. \n• Soil water showed strong regional contrasts, with extreme dryness in South America and Southern Africa and \nwet conditions in West Africa. \n• Vegetation condition was the highest since 2001, continuing a steady increase. Drought impacts on vegetation \nwere strongest in the Amazon region and Southern Africa. \n• Surface water extent over land was close to average. There has been an increasing trend in record-high \nmonthly water extent globally of 3% per decade since 2003. \n• River flows were very low in northern South America and high in Western, Central and Eastern Africa. There \nhas been an increasing trend in record-high flows of 21% per decade since 2001. \n• Lake and reservoir water storage worldwide declined for the fifth year in a row, with unprecedented lows in \nSouth America and record-high levels in Africa.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 4, 'page_label': '5'}, page_content="|  \n                     5 \n• Terrestrial water storage – underground and in surface water, ice and snow combined − showed ongoing low \nvalues in 2024 in most of the world's dry regions but strong increases in western, Central and Eastern Africa. \nMajor water-related disasters \nIn 2024, water-related disasters caused more than 8,700 fatalities, displaced 40 million people, and resulted in \neconomic losses exceeding US$550 billion globally, with true figures likely higher due to incomplete data and events \nnot listed. The most damaging events included riverine floods, flash floods, landslides, droughts, and tropical cyclones, \nin terms of:  \n• Human Tragedy: Flash floods and landslides together caused tens of thousands of fatalities worldwide, with \nmajor events in Africa, South Asia and Papua New Guinea leading the toll. \n• Displacement: River floods across the Sahel region and drought in Southern Africa displaced over 30 million \npeople and exacerbated food insecurity across vast regions. \n• Food Security: Droughts were devastating, with Southern Africa alone experiencing a halving of crop \nproduction, leaving more than 30 million people facing food shortages. \n• Economic Damage: Tropical cyclones resulted in economic damages exceeding US$520 billion globally, \nparticularly in the USA and Southeast Asia, making them the costliest disaster in 2025 by far. \n• Ecological Impact: Droughts and deforestation-related fires caused profound harm to the Amazon rainforest, \nwith over 52 thousand km2 of forest lost to fire in September alone."),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page':
document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 7, 'page_label': '8'}, page_content='8                 \n   |  \n  \n \n \n \nSince the first Earth-observing satellite was launched \nsixty years ago, satellite remote sensing has become a \ncrucial part of weather observation and forecasting \nsystems worldwide. In more recent decades, the use of \nsatellites to observe water at and below the Earth’s \nsurface has developed into practical solutions. Ideally, \nsatellite measurements are calibrated to on-ground \nmeasurements where they exist to increase their \naccuracy. Once calibrated, they can provide \ninformation much faster, over much larger areas and \nwith much greater detail than the on-ground \nmeasurement network alone.  \nAll data discussed in this report were developed using \nmethods that have been published: \nPrecipitation and weather data are estimated by \ncombining the latest satellite observations with all \nglobally available weather station data and information \nfrom weather forecasting models1 \nSoil water is interpreted from measurements by \npassive and active (radar) satellite microwave \ninstruments and made available by the EU Copernicus \nClimate Data Store2 \nSurface water occurrence, including lakes, rivers and \nother forms of (temporary) inundation, was mapped \nusing NASA’s MODIS satellite imagery3. \nRiver flows are estimated by automated measurement \nof river width in satellite imagery4  \nLake and reservoir volume is estimated by combining \nsatellite measurements of surface water level and \nextent with topography5. \n \n1 Beck et al., Bulletin American Meteorological Society , 2019 (link) and \n2022 (link) \n2 Copernicus Climate Data Store (link, v202012 combined product) \n3 NASA and USGS Earth Data (link) \nVegetation condition (NDVI) responds to water \navailability and is observed by NASA’s MODIS \nsatellites3.  \nTerrestrial water storage, including groundwater, soil \nwater, surface water, snow and land ice, is derived from \ngravity measurements by the GRACE Follow-On \nsatellites6. Missing data were imputed using a deep-\nlearning approach7 \nThe key objective of the Global Water Monitor is to \nmake up-to-date, global and accurate climate and \nwater information freely available and easily \naccessible. We developed a visual data explorer, the \nGlobal Water Monitor (www.globalwater.online). All \ndata shown in this report are directly derived from that \nwebsite and, therefore, can be reproduced or examined \nin more detail. Users can retrieve and visualise maps or \ntime series for any location, administrative \nhydrological region or hand-drawn area. Some \nbackground on the calculations and interpretations \navailable and as used in this report is provided below. \nThe ‘normal’ range of climate and water conditions \nvaries worldwide, from arid deserts to tropical \nmonsoon regions and frozen poles. Percentages and \nanomalies are insightful ways of comparing actual \nvalues to the distribution of values for the same area \nand time of year in the historical record. The metrics \navailable in the Global Water Monitor and used in this \nreport are: \nAnomaly or absolute difference from mean provides \ninformation on the departure from long-term average \n4 Hou et al., Remote Sensing of Environment, 2022 (link) \n5 Hou et al., Hydrology and Earth System Sciences, 2022 (link) \n6 Boergens et al. (2019) (link), also available from GraVIS (link) \n7 Mo et al. (in press)'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='|  \n                     9 \nconditions. For example, rainfall in a particular period \n(e.g., March to September) may be 100 mm more than \nthe average for the same period in all previous years. \nPercentage of the mean puts the same information in a \nrelative context. For example, the same 100 mm \ndifference would be 110% of (or 10% above) a longer-\nterm average value of 1000 mm. \nStandardised anomaly or σ (sigma) value is a useful \nmeans to compare the actual conditions to previous \nyears in a way that accounts for the year-to-year \nvariation experienced historically. It is calculated by \ndividing the actual anomaly by the standard deviation \nof values in previous years. Below is a general \ninterpretation of the colour scale used in most maps in \nthis report. Extremely high or low values often coincide \nwith record values in the time series, but that is not \nautomatically the case. \n \nColour legend and interpretation of standard anomalies. Note that \ncolours are reversed for air temperature to be more intuitive. For \nreference, this figure is also provided in the back of the report (p. 57).  \nSummaries were calculated by country as defined by \nthe International Organisation for Standardization (ISO \n3166-1) and include the 193 UN member countries as \nwell as other administrative entities. In the Global \nWater Monitor, summary data are also available for \nsubnational regions (e.g., states and provinces). No \npolitical statement is intended by use of the ISO and \nUN lists. \nMany river basins cover more than one country and \nconversely, large countries may contain multiple river \nbasins. Therefore, summaries were also calculated by \nriver basin. In the case of islands and coastal regions \nwith multiple small catchments, river ‘basins’ can be a \nseries of bordering catchments. In the Global Water \nMonitor, summary data are also available for individual \nsmaller catchments within basins.  \nIf there are no gaps in the data, averages across \ncountries or catchments can be calculated directly. If \nthere are some missing data, they can be estimated. \nHowever, if most data are missing, calculated averages \ncan be misleading.  \nSummarising storage in lakes by country or basin is \nstraightforward in principle, as they can be added up. \nHowever, not all water bodies are measured all the \ntime, and gaps in the data need to be estimated.  \nSummarising river flows by country or catchment is \nchallenging. For example, many countries contain \nmultiple rivers. We selected the fifteen river \nobservation locations with the largest long-term \naverage flows within the country or catchment and \ncalculated a weighted average value. By its very nature, \naveraging over years and regions can hide locally \nsevere conditions or extreme events that occur over \nshort periods. This should be kept in mind when \ninterpreting the information. \nSatellite instruments can provide a near-immediate \nglobal overview of climate and water conditions, but \nthey have uncertainties. Where available, onsite \nobservations are usually more accurate and necessary \nto calibrate remote sensing approaches like those used \nhere. Protecting and expanding the remaining water \nmeasurement station network should be a priority.  \nRecord length, frequency and spatial detail vary \nbetween data sources. For example, climate data are \navailable from 1979, water body data from 1984, soil \nwater data from 1991, river flow data from 2000, and \nterrestrial water storage data from 2002 onwards.  \nEven satellite observations are unavailable in some \nregions and at some times. For ...
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 9, 'page_label': '10'}, page_content='10                 \n   |'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 10, 'page_label': '11'}, page_content='|  \n                     11 \n \n \n \n \nThe global land area average annual precipitation was \n798 mm, 11.6 mm higher than the baseline. There is a \nstatistically significant declining trend in global \nprecipitation of 0.65 mm per year (−0.08% annually \nrelative to the baseline). \n \n \nAverage annual precipitation over land. \nRecord-high monthly precipitation values were 27% \nhigher than for the baseline period, but there is no \nsignificant trend.  \nThe frequency of record-low monthly precipitation \nvalues in the 4,687 catchments worldwide was 38% \nhigher than the 1995–2005 average. There is a \nsignificant increasing trend of 3.8% per decade in \nrecord-low months.  \n \nThe number of times high monthly precipitation records were broken   \nrelative to the baseline period 1995–2005  \n \n \nThe number of times low monthly precipitation records were broken \nrelative to the baseline period 1995–2005'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page':
document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 14, 'page_label': '15'}, page_content='|  \n                     15 \n \n \n \n \nGlobally, 2024 was the hottest year on record over \nland. Air temperature across land was 1.2°C above the \n1995–2005 average. There has been a statistically \nsignificant increase of 0.35°C per decade. \n \n \nAnnual average temperature over the global land area.  \n \nThe number of record-high monthly average \ntemperatures in the 4,687 river catchments worldwide \nwas the highest in the 45-year record and 9.3 times the \n1995–2005 average. There has been a rapid increase \nin record-breaking high monthly temperatures of 97% \nper decade. \nThe number of record-low monthly average \ntemperatures was 85% less frequent than the baseline \naverage. There is a significant decreasing trend of \n−66% fewer record-breaking low monthly average \ntemperatures per decade. \n \nThe number of times high monthly average temperature records were \nbroken compared to the average for 1995–2005.  \n \nThe number of times low monthly temperature records were broken \ncompared to the average for 1995–2005.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 15, 'page_label': '16'}, page_content='16                 \n   |  \n  \nNo countries recorded unusually low \nannual air temperatures in 2024, whereas \n111 countries recorded record-high \ntemperatures. They included 30 out of the \n54 countries in Africa, 24 out of 44 in \nEurope, 22 out of 49 in Asia, 26 out of 35 \nin South America, and 9 out of 14 in \nOceania. A further thirteen countries \nrecorded unusually high but not record \ntemperatures, including Canada.  \nNo river basins experienced unusually \nlow annual air temperatures in 2024, \nwhereas record-high temperatures were \nobserved in 111 out of 292 river basins \nglobally. They included the Amazonas \nand Orinoco basins in South America; the \nCongo, Niger, Nile, and Zambezi basins in \nAfrica; the Yangtze and Mekong in Asia \nand the Danube basin in Europe.  \nAnother thirty-four basins recorded \nunusually high but not record annual \ntemperatures, including the Orange and \nOkavango basins in Africa.\n \n \n  \nStandardised anomaly in annual average air temperature (see p.9 or p. 57 for legend - \nnote the colour scale is reversed for temperature, with red showing higher \ntemperatures)  \n \nBy country \n \nBy river basin'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 16, 'page_label': '17'}, page_content='|  \n                     17 \n \n \n \n \nIn 2024, the annual maximum temperature − averaged \nover all catchments worldwide − was 1.2°C higher than \nfor the 1995–2005 baseline period. There has been a \nstatistically significant upward trend of 0.33°C per \ndecade. The global average number of hot days (days \nreaching 35°C) was 33% higher than the baseline \nperiod and also showed a statistically significant \nupward trend of 8.4% per decade. \n \n \nAnnual maximum temperature (top) and number of hot days (bottom) \nover the global land area. \nRecord-high monthly maximum temperatures across \nall catchments worldwide were 5.6 times more \nfrequent in 2024 than during the baseline period and \nshowed a significant increasing trend of 64% per \ndecade. For hot days, record-high monthly numbers \nwere 8.0 times more frequent in 2024, with a \nsignificant increasing trend of 1.3% per decade. \n \n \nAnnual number of times monthly record high maximum temperature \n(top) and number of hot days (bottom) occurred in the time series \nrelative to the baseline period (1995–2005).'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 17, 'page_label': '18'}, page_content='18                 \n   |  \n  \n \nNo countries experienced unusually low \nmaximum temperatures or hot days in \n2024. Record-high annual maximum \ntemperatures were observed in 34 \ncountries, and record-high hot days in 40 \ncountries. Sixteen countries experienced \nunusual, extreme or record-high \nmaximum temperatures and number of \nhot days. These include nine countries in \nAfrica (Nigeria, Mali, Senegal, Chad, \nCameroon, Gabon, Central African \nRepublic, Ethiopia, and Madagascar), two \nin Southeast Asia (Laos and Myanmar), \ntwo in Central America (Guatemala and \nHonduras) and three in Oceania (Papua \nNew Guinea, Samoa and Nauru). \nNo river basins recorded unusually low \nmaximum temperature or number of hot \ndays. However, many river basins \nexperienced record or unusually high \nvalues for either. Fifteen river basins \nexperienced both. They include the \nCongo, Niger, Zambezi, and Shebelli-Juba \nbasins and the Nigerian and West African \nCoast in Africa; the Orinoco and Central \nAmerica Pacific Coast in the Americas; \nthe Mekong, Vietnam Coast, and Persian \nGulf Coast in Asia; Sumatra and Papua in \nOceania; and the Tyrrhenian and East \nMediterranean Coasts in Europe.\n \n \n  \nStandardised anomaly in annual maximum air temperature (see p.9 or p.57 for legend \n- note the colour scale is reversed for temperature, with red showing higher \ntemperatures)  \n \nBy country \n \n \nStandardised anomaly in annual number of hot days'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 18, 'page_label': '19'}, page_content='|  \n                     19 \n \n \n \n \nIn 2024, the global average annual minimum air \ntemperature over land was 0.81°C higher than the \n1995–2005 baseline. There has been a statistically \nsignificant upward trend of 0.34°C per decade.  \nThe global number of frost days (temperatures falling \nbelow 0°C) over land was 7.2% less than for the 1995–\n2005 baseline, with a statistically significant downward \ntrend of −2.2% per decade relative to the baseline.  \n \n \nAverage annual minimum temperature (top) and number of frost days \n(bottom) over the global land area. \nRecord-high monthly minimum temperatures across \n4,687 catchments worldwide were 7.1 times more \nfrequent than during the baseline period, with a \nsignificant increasing trend of 72% per decade. Months \nwith record-low numbers of frost days were 22% more \nfrequent than during the baseline period, with a \nsignificant increasing trend of 10% per decade. \nConversely, record-low monthly minimum \ntemperatures were 66% less frequent than during the \nbaseline period, with a statistically significant \ndecreasing trend of −43% per decade. Months with a \nrecord-high number of frost days were 1.5% less \nfrequent, with a significant decreasing trend of −1.1% \nper decade. \n \n \nAnnual number of times monthly record high minimum temperature \n(top) and number of frost days (bottom) occurred in the time series \nrelative to the baseline period (1995–2005).'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 19, 'page_label': '20'}, page_content='20                 \n   |  \n  \nTwenty-eight countries experienced \nrecord-high annual minimum \ntemperatures, including eleven countries \nin Africa, eight in Western Asia, four in the \nCaribbean, two Micronesian nations, \nSuriname in South America, Brunei \nDarussalam in Southeast Asia, and Malta \nin Southern Europe. Unusually but not \nrecord-high annual minimum \ntemperatures were recorded in a further \n16 countries in Asia, Africa, around the \nCaribbean, and Polynesia. No country \nexperienced extremely low minimum \ntemperatures. \nTwelve countries experienced record few \ndays with frost, including China, \nMongolia, North Korea, Iran and Iraq in \nAsia; Switzerland, Poland, Moldova and \nUkraine in Europe; Morocco in Northern \nAfrica; and Canada and Bolivia in the \nAmericas. A further thirteen countries \nexperienced an unusual but not record-\nlow number of frost days, including ten in \nEurope and India, Pakistan and \nKyrgyzstan in Asia. Uruguay in South \nAmerica was the only country to \nexperience an unusually high number of \nfrost days. \nRecord high annual values were observed \nin 42 out of 292 river basins. Of these, \neleven were in Africa, including the Horn \nof Africa and Rift Valley; eight in Asia, \nincluding the Tigris-Euphrates and \nJordan basins; ten in Oceania, including \nSumatra and North Papua Islands; six in \nSouth America, including the Magdalena \nbasin and Venezuela Coast; three in \nEurope, including the East Mediterranean \nCoast; the US North Atlantic Coast; and \nthree Arctic basins. Another seventeen \nbasins recorded unusually high annual values, \nincluding the Niger and Volta basins in Africa, the \nArabian Peninsula, and the Orinoco basin in South \nAmerica. \nTwenty-seven river basins experienced a record-low \nnumber of frost days: twelve in Asia, including several \noriginating in the Himalayas and basins in Mongolia; \nfour in Europe; two in Africa; two in South America; four \nin North America; and three in the Arctic. Another nine \nbasins recorded unusual but not record-low number of \nfrost days, including three in Asia, four in Europe (e.g., \nthe Danube) and two in the Arctic. South America’s La \nPlata basin was the only basin worldwide with an \nunusually high but not record number of frost days in \n2024. \nStandardised anomaly in annual minimum air temperature (see p.9 or p.57 for legend \n- note the colour scale is reversed for temperature, with red showing higher \ntemperatures)  \n \nBy country \n \nStandardised anomaly in annual number of frost days.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 20, 'page_label': '21'}, page_content='|  \n                     21 \n \n \n \n \n \n \n \nThe global average relative air humidity over land was \n64% in 2024, lower than the 1995–2005 baseline of \n65% but the highest since 2018. There is a statistically \nsignificant long-term decline of approximately 0.5% per \ndecade (−0.8% relative to the baseline average). The \ntrend towards drier air has been attributed to a more \nrapid rise in air temperature over land than over sea9.  \n \nAnnual average air humidity over the global land area  \nRecord-low monthly values in 2024 across 4,687 river \ncatchments worldwide occurred at a frequency 2.2 \ntimes higher than the baseline. The annual frequency \nof record-low values has been increasing at a \nstatistically significant rate of 25% per decade. Low air \nhumidity exacerbates drought impacts on ecosystems \nand people and increases the risk and severity of \n \n9 Seneviratne et al. (2021) (link) \nbushfires. Record-high monthly values were 4.3% \nlower than the baseline. There has been a statistically \nsignificant decrease of −15% per decade. \n \nThe number of times low monthly air humidity records were broken \ncompared to the average for 1995–2005 \n \nThe number of times high monthly air humidity records were broken \ncompared to the average for 1995–2005.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 21, 'page_label': '22'}, page_content='22                 \n   |  \n  \n \nThirteen countries recorded record-low \nannual relative humidity values. In Africa, \nrecord lows were reported in the Democratic \nRepublic of Congo, Republic of Congo, Gabon, \nEquatorial Guinea, the Central African \nRepublic, and Botswana. In Eastern Europe, \nUkraine, Romania, and Bulgaria had record-\nlow air humidity. South America saw record \nlows in Brazil, Peru, Ecuador, and Guyana. Five \nadditional countries experienced unusually \nlow annual values. These included Bolivia, \nColombia, and Venezuela in South America, as \nwell as Madagascar and South Sudan in \nEastern Africa. \nTwo countries recorded record-high annual \nvalues: Niger in Western Africa and the \nDominican Republic in the Caribbean. Three \nmore countries experienced unusually high \nvalues: India, Oman in Western Asia, and \nSenegal in Western Africa. \nAmong the 292 river basins analysed, nine \nrecorded record-low annual values. In South \nAmerica, record lows were observed in the \nAmazon, Guyana Coast, Marajo, and Ecuador-\nColombia Pacific Coast basins. In Africa, the \nZambezi, Congo, and Ogooue-Sanaga basins \nsaw significant declines. The Crimea basin in \nEurope and the Yana-Indigirka-Kolyma basin \nin Siberia also reached record-low values. \nFurthermore, seven basins experienced \nunusually low values, including the Cross and \nOkavango basins in Africa, the Black Sea \nNorth Coast and Don basins in Europe, and \nthe Colombia Caribbean Coast and Orinoco \nbasins in South America. \nSeven basins recorded record-high annual \nrelative humidity levels. In Africa, the Agadez-\nEnnedi basin experienced unprecedented \nvalues. In Asia, records were set on the Indian \nArabian Sea Coast. Three Arctic basins also \nreported record highs. Six additional basins \nshowed unusually high values, including the \nNorthwest Sudan basin in Africa, the India \nBengal Coast and Arabian Sea Coast basins, \nShetland in Europe, and two Arctic basins.  \n \nStandardised anomaly in annual average air humidity (see p.9 or p.57 for legend) \n \nBy country \n \nBy river basin \n \n.'),
#   Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 22, 'page_label': '23'}, page_content='|  \n                     23 \n \n \n \nThe global annual average near-surface soil moisture \nin 2024 was 21 vol%, a slight increase of 1% more than \nthe 1995–2005 baseline, or 2.4% in relative terms. \nGlobal average soil water conditions appear to \noscillate over time. There is no statistically significant \nlong-term trend. \nSatellite instruments measure soil water near the \nsurface only, which can respond more to rainfall \nfrequency than the total amount and can also be \naffected by agriculture and vegetation changes.  \n \n \nAnnual soil water content over the global land area.  \n \nRecord-low monthly values in catchments worldwide \noccurred 31% more than during the baseline, whereas \nrecord-high monthly values occurred 54% more often, \nbut there was no statistically significant trend in either.  \nThe record combines a series of satellite instruments, \nand inconsistencies between sensors may cause some \nof the shifts. \n \nThe number of times high monthly soil water records were broken \ncompared to the average for 1995–2005. \n \nThe number of times low monthly soil water records were broken \ncompared to the average for 1995–2005.'),
# ...
#   Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content='Copyright ©Afrobarometer 2024  18 \n \nFigure 19: Government performance on providing water and sanitation services                 \n| by urban-rural location and lived poverty | 39 countries | 2021/2023 \n \nRespondents were asked: How well or badly would you say the current government is handling the \nfollowing matters, or haven’t you heard enough to say: Providing water and sanitation services?  \n \nSeychelles – which recorded the largest proportion of households that “never” went without \nenough water (88%) (Figure 7) – is an outlier here, with 87% approval of the government’s \nperformance on water and sanitation, followed by Tanzania (64%). But fewer than one in five \ncitizens praise their government’s efforts on water/sanitation in Gabon (13%), Sudan (13%), \nCongo-Brazaville (15%), Liberia (17%), Angola (17%), and Nigeria (19%) (Figure 20).  \nAcross the 30 countries that have tracked this indicator consistently since 2011/2013, pos itive \nassessments of government performance on water/sanitation have always been in the \nminority, increasing modestly until 2016/2018 (44%) but then dropping back to 2011/2013 \nlevels (Figure 21). \nSince 2011/2013, public assessments of the government’s performance have improved \nsignificantly (by more than 3 percentage points) in 11 of the 31 countries for which we have \ncomparable data, including huge gains in Tanzania (+31 points) and Niger (+25 points) \n(Figure 22).  \nWhile holding fairly steady in eight countries, approval declined significantly in 12 countries, \nmost dramatically in South Africa (-28 points) and Sudan (-25 points) (Figure 23). \n  \n38% 36% 41%\n25%\n35%\n49% 58%\n61% 63% 58%\n75%\n64%\n51%\n41%\n0%\n20%\n40%\n60%\n80%\n100%\nFairly well/Very well Fairly badly/Very badly'),
#   Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source
022 2013, 2015, 2018, 2021 \nTanzania Sept.-Oct. 2022 2001, 2003, 2005, 2008, 2012, 2014, 2017, 2021 \nTogo March 2022 2012, 2014, 2017, 2021 \nTunisia Feb.-March 2022 2013, 2015, 2018, 2020 \nUganda Jan. 2022 2000, 2002, 2005, 2008, 2012, 2015, 2017, 2019 \nZambia Aug.-Sept. 2022 1999, 2003, 2005, 2009, 2013, 2014, 2017, 2020 \nZimbabwe March-April 2022 1999, 2004, 2005, 2009, 2012, 2014, 2017, 2021"),
#   Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content='Copyright ©Afrobarometer 2024  24 \n \n \n \nMohamed Najib Ben Saad is a data quality officer for Afrobarometer in Tunisia.                 \nEmail: mohamednajibbensaad@afrobarometer.org. \nGeorge William Kayanja is a researcher for Hatchile Consult Ltd. in Uganda.                         \nEmail: georgew@hatchileconsult.com. \nStevenson Male Ssevume is a researcher for Hatchile Consult Ltd. in Uganda.                          \nEmail: stevenson@hatchileconsult.com                    \nAfrobarometer, a nonprofit corporation with headquarters in Ghana, is  a pan-African, non-\npartisan research network. Regional coordination of national partners in about 35 countries is \nprovided by the Ghana Center for Democratic Development (CDD-Ghana), the Institute for \nJustice and Reconciliation (IJR) in South Africa, and the Institute for Development Studies \n(IDS) at the University of Nairobi in Kenya. Michigan State University (MSU) and the University \nof Cape Town (UCT) provide technical support to the network. \nFinancial support for Afrobarometer is provided by Sweden via the Swedish International \nDevelopment Cooperation Agency, the U.S. Agency for International Development (USAID) \nvia the U.S. Institute of Peace, the Mo Ibrahim Foundation, the Open Society Foundations  - \nAfrica, Luminate, the William and Flora Hewlett Foundation, the Bill & Melinda Gates \nFoundation, the Mastercard Foundation, the David and Lucile Packard Foundation, the \nEuropean Union Commission, the World Bank Group, the Ministry of Foreign Affairs of Finland, \nthe Embassy of the Kingdom of the Netherlands in Uganda, the Embassy of Sweden in \nZimbabwe, the Global Centre for Pluralism, and GIZ. \nDonations help Afrobarometer give voice to African citizens. Please consider making a \ncontribution (at www.afrobarometer.org) or contact Felix Biga (felixbiga@afrobarometer.org ) \nor Runyararo Munetsi (runyararo@afrobarometer.org) to discuss institutional funding. \nFor more information, please visit www.afrobarometer.org. \nFollow our releases on #VoicesAfrica.  \n                             /Afrobarometer                  @Afrobarometer                          \nAfrobarometer Dispatch No. 784 | 19 March 2024')]]

# %%
#split the pdf files into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter


def split_pdfs_into_chunks(documents, chunk_size=1000, chunk_overlap=100):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    chunks = []
    for doc in documents:
        chunks.extend(text_splitter.split_documents(doc))
    return chunks


pdf_chunks = split_pdfs_into_chunks(pdf_documents)
pdf_chunks
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 0, 'page_label': '1'}, page_content='|  \n                     1'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 1, 'page_label': '2'}, page_content='2                 \n   |  \n  \n \n \n \n \n \nDisclaimer \nThe material in this report is of a general nature and should not be regarded as legal advice or relied on for assistance in any \nparticular circumstance or emergency situation. In any important matter, you should seek appropriate independent \nprofessional advice in relation to your own circumstances. The Australian National University and the Global Water Monitor \nConsortium partners accept no responsibility or liability for any damage, loss or expense incurred as a result of reliance on  the \ninformation contained in this report.  \n \n \n \n \n \n \n \n \nHow to cite:  \nVan Dijk, A.I.J.M., H.E. Beck, E. Boergens, R.A.M. de Jeu, W.A. Dorigo, C. Edirisinghe, E. Forootan, E. Guo, A. Güntner, J. Hou, N. \nMehrnegar, S. Mo, W. Preimesberger, J. Rahman, P. Rozas Larraondo (202 5) Global Water Monitor 2024, Summary Report. \nPublished by Global Water Monitor Consortium, available at www.globalwater.online'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 1, 'page_label': '2'}, page_content='Published by Global Water Monitor Consortium, available at www.globalwater.online  \n \n  \n \n© Australian National University, 2025 \nThe CC BY licence is a standard form licence agreement that allows you to copy and redistribute the material in any medium \nor format, as well as remix, transform, and build upon the material, on the condition that you provide a link to the licence,  you \nindicate if changes were made, and you attribute the material as follows: Licensed by the Global Water Monitor Consortium \nunder a Creative Commons Attribution 4.0 International licence.  \n \n \nFront cover image: Sentinel-2 satellite image of part of Lake Chad in Western Africa in November 2024, having filled after an unusually wet \nmonsoon season.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 2, 'page_label': '3'}, page_content="|  \n                     3 \n \nOur global water systems are under mounting pressure as climate change drives more extreme weather events and \ndisrupts the water cycle. The year 2024 was a year of extremes but not an isolated occurrence. It fits with a worsening \ntrend of more intense floods, prolonged droughts, and record-breaking extremes. These changes impact water \navailability and increase the risks to lives, infrastructure and ecosystems from water-related disasters. \nReliable and timely information about water resources and hazards is more crucial than ever, yet traditional ground-\nbased measurement networks continue to decline. Satellite observations now play a vital role, offering rapid and \nconsistent global data on the atmosphere and Earth's surface, but they should not replace networks on the ground. \nThe Global Water Monitor Consortium unites public and private organisations to deliver open, actionable climate and"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 2, 'page_label': '3'}, page_content='water data. By integrating satellite and ground observations, we aim to provide timely updates on critical aspects of the \nwater cycle. Our Global Water Monitor platform (www.globalwater.online) allows anyone to explore a wealth of climate \nand water data free of charge. \nThis third annual report builds on the work of previous years, summarising the state of the global water cycle in 2024, \nidentifying key trends, and analysing major hydrological events. It includes updated metrics on rainfall, temperature, air \nhumidity, river flows and water stored in lakes, soil and underground. It also provides insights into extreme rainfall and \ntemperatures. \nThis report reinforces a clear message: as the planet warms, water challenges are escalating, year after year. By trying \nto provide information on changes and events, we hope to support informed decision-making to protect communities, \ninfrastructure, and ecosystems in an increasingly volatile future \n2 January 2025 \n \nAlbert van Dijk'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 2, 'page_label': '3'}, page_content='2 January 2025 \n \nAlbert van Dijk \nProfessor of Water Science and Management, Australian National University \nChair, Global Water Monitor Consortium'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 3, 'page_label': '4'}, page_content='4                 \n   |  \n  \n \n \nAbout this report \nThe Global Water Monitor provides free, rapid, global information on climate and water resources. This summary report \ncontains information on rainfall, air temperature, humidity, soil and groundwater conditions, vegetation condition, river \nflows, flooding, and lake volumes in 2024. Trends in the water cycle and some of the most important hydrological \nevents of 2024 are interpreted and discussed. \nGlobal summary \nKey aspects of the water cycle in 2024 over the global land area were: \n• Precipitation over land was close to the 1995–2005 average. Extremely dry months have become increasingly \ncommon in recent decades, with 38% more record-dry months in 2024 than for the baseline period. \n• Daily precipitation extremes were 52% more common in 2024 than during 1995–2005, with record-breaking \ndaily rainfall events in West Africa, Europe and Asia. There has been a significant increasing trend of 4% per \ndecade over land.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 3, 'page_label': '4'}, page_content='decade over land. \n• Average temperature over land was the highest recorded globally and in 111 countries, and globally 1.2°C \nabove the 1995–2005 average. The frequency of record-warm months was the highest since 1979. \n• High temperature: new records were set for annual maximum temperature in 34 countries and hot days in 40 \ncountries. Both show increasing trends. \n• Low temperatures: globally, the number of frost days over land was the lowest on record. Annual minimum \ntemperatures are increasing, especially in the tropics. \n• Relative air humidity over land was the highest since 2018, but a declining trend remains. Humidity was very \nlow in South America and Central Africa in 2024. \n• Soil water showed strong regional contrasts, with extreme dryness in South America and Southern Africa and \nwet conditions in West Africa. \n• Vegetation condition was the highest since 2001, continuing a steady increase. Drought impacts on vegetation'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 3, 'page_label': '4'}, page_content='were strongest in the Amazon region and Southern Africa. \n• Surface water extent over land was close to average. There has been an increasing trend in record-high \nmonthly water extent globally of 3% per decade since 2003. \n• River flows were very low in northern South America and high in Western, Central and Eastern Africa. There \nhas been an increasing trend in record-high flows of 21% per decade since 2001. \n• Lake and reservoir water storage worldwide declined for the fifth year in a row, with unprecedented lows in \nSouth America and record-high levels in Africa.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 4, 'page_label': '5'}, page_content="|  \n                     5 \n• Terrestrial water storage – underground and in surface water, ice and snow combined − showed ongoing low \nvalues in 2024 in most of the world's dry regions but strong increases in western, Central and Eastern Africa. \nMajor water-related disasters \nIn 2024, water-related disasters caused more than 8,700 fatalities, displaced 40 million people, and resulted in \neconomic losses exceeding US$550 billion globally, with true figures likely higher due to incomplete data and events \nnot listed. The most damaging events included riverine floods, flash floods, landslides, droughts, and tropical cyclones, \nin terms of:  \n• Human Tragedy: Flash floods and landslides together caused tens of thousands of fatalities worldwide, with \nmajor events in Africa, South Asia and Papua New Guinea leading the toll. \n• Displacement: River floods across the Sahel region and drought in Southern Africa displaced over 30 million"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 4, 'page_label': '5'}, page_content='people and exacerbated food insecurity across vast regions. \n• Food Security: Droughts were devastating, with Southern Africa alone experiencing a halving of crop \nproduction, leaving more than 30 million people facing food shortages. \n• Economic Damage: Tropical cyclones resulted in economic damages exceeding US$520 billion globally, \nparticularly in the USA and Southeast Asia, making them the costliest disaster in 2025 by far. \n• Ecological Impact: Droughts and deforestation-related fires caused profound harm to the Amazon rainforest, \nwith over 52 thousand km2 of forest lost to fire in September alone.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page':
),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 6, 'page_label': '7'}, page_content='Southeast Asia ......................................................................................................................................................................42 \nKazakhstan-Russia ..............................................................................................................................................................43 \nSouthern Africa .....................................................................................................................................................................44 \nEast Africa .............................................................................................................................................................................45 \nSouth Sudan ..........................................................................................................................................................................46'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 6, 'page_label': '7'}, page_content='West and Central Africa ........................................................................................................................................................47 \nCentral Europe .......................................................................................................................................................................48 \nSpain ......................................................................................................................................................................................49 \nSoutheastern USA .................................................................................................................................................................50 \nAmazon Basin .......................................................................................................................................................................51'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 6, 'page_label': '7'}, page_content='Southern Brazil .....................................................................................................................................................................52 \nPapua New Guinea ...............................................................................................................................................................53 \nOutlook for 2025 ........................................................................................................................................................................54 \nAbout Us ....................................................................................................................................................................................56'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 7, 'page_label': '8'}, page_content='8                 \n   |  \n  \n \n \n \nSince the first Earth-observing satellite was launched \nsixty years ago, satellite remote sensing has become a \ncrucial part of weather observation and forecasting \nsystems worldwide. In more recent decades, the use of \nsatellites to observe water at and below the Earth’s \nsurface has developed into practical solutions. Ideally, \nsatellite measurements are calibrated to on-ground \nmeasurements where they exist to increase their \naccuracy. Once calibrated, they can provide \ninformation much faster, over much larger areas and \nwith much greater detail than the on-ground \nmeasurement network alone.  \nAll data discussed in this report were developed using \nmethods that have been published: \nPrecipitation and weather data are estimated by \ncombining the latest satellite observations with all \nglobally available weather station data and information \nfrom weather forecasting models1 \nSoil water is interpreted from measurements by'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 7, 'page_label': '8'}, page_content='from weather forecasting models1 \nSoil water is interpreted from measurements by \npassive and active (radar) satellite microwave \ninstruments and made available by the EU Copernicus \nClimate Data Store2 \nSurface water occurrence, including lakes, rivers and \nother forms of (temporary) inundation, was mapped \nusing NASA’s MODIS satellite imagery3. \nRiver flows are estimated by automated measurement \nof river width in satellite imagery4  \nLake and reservoir volume is estimated by combining \nsatellite measurements of surface water level and \nextent with topography5. \n \n1 Beck et al., Bulletin American Meteorological Society , 2019 (link) and \n2022 (link) \n2 Copernicus Climate Data Store (link, v202012 combined product) \n3 NASA and USGS Earth Data (link) \nVegetation condition (NDVI) responds to water \navailability and is observed by NASA’s MODIS \nsatellites3.  \nTerrestrial water storage, including groundwater, soil \nwater, surface water, snow and land ice, is derived from'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 7, 'page_label': '8'}, page_content='water, surface water, snow and land ice, is derived from \ngravity measurements by the GRACE Follow-On \nsatellites6. Missing data were imputed using a deep-\nlearning approach7 \nThe key objective of the Global Water Monitor is to \nmake up-to-date, global and accurate climate and \nwater information freely available and easily \naccessible. We developed a visual data explorer, the \nGlobal Water Monitor (www.globalwater.online). All \ndata shown in this report are directly derived from that \nwebsite and, therefore, can be reproduced or examined \nin more detail. Users can retrieve and visualise maps or \ntime series for any location, administrative \nhydrological region or hand-drawn area. Some \nbackground on the calculations and interpretations \navailable and as used in this report is provided below. \nThe ‘normal’ range of climate and water conditions \nvaries worldwide, from arid deserts to tropical \nmonsoon regions and frozen poles. Percentages and'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 7, 'page_label': '8'}, page_content='varies worldwide, from arid deserts to tropical \nmonsoon regions and frozen poles. Percentages and \nanomalies are insightful ways of comparing actual \nvalues to the distribution of values for the same area \nand time of year in the historical record. The metrics \navailable in the Global Water Monitor and used in this \nreport are: \nAnomaly or absolute difference from mean provides \ninformation on the departure from long-term average \n4 Hou et al., Remote Sensing of Environment, 2022 (link) \n5 Hou et al., Hydrology and Earth System Sciences, 2022 (link) \n6 Boergens et al. (2019) (link), also available from GraVIS (link) \n7 Mo et al. (in press)'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='|  \n                     9 \nconditions. For example, rainfall in a particular period \n(e.g., March to September) may be 100 mm more than \nthe average for the same period in all previous years. \nPercentage of the mean puts the same information in a \nrelative context. For example, the same 100 mm \ndifference would be 110% of (or 10% above) a longer-\nterm average value of 1000 mm. \nStandardised anomaly or σ (sigma) value is a useful \nmeans to compare the actual conditions to previous \nyears in a way that accounts for the year-to-year \nvariation experienced historically. It is calculated by \ndividing the actual anomaly by the standard deviation \nof values in previous years. Below is a general \ninterpretation of the colour scale used in most maps in \nthis report. Extremely high or low values often coincide \nwith record values in the time series, but that is not \nautomatically the case. \n \nColour legend and interpretation of standard anomalies. Note that'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='automatically the case. \n \nColour legend and interpretation of standard anomalies. Note that \ncolours are reversed for air temperature to be more intuitive. For \nreference, this figure is also provided in the back of the report (p. 57).  \nSummaries were calculated by country as defined by \nthe International Organisation for Standardization (ISO \n3166-1) and include the 193 UN member countries as \nwell as other administrative entities. In the Global \nWater Monitor, summary data are also available for \nsubnational regions (e.g., states and provinces). No \npolitical statement is intended by use of the ISO and \nUN lists. \nMany river basins cover more than one country and \nconversely, large countries may contain multiple river \nbasins. Therefore, summaries were also calculated by \nriver basin. In the case of islands and coastal regions \nwith multiple small catchments, river ‘basins’ can be a \nseries of bordering catchments. In the Global Water'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='series of bordering catchments. In the Global Water \nMonitor, summary data are also available for individual \nsmaller catchments within basins.  \nIf there are no gaps in the data, averages across \ncountries or catchments can be calculated directly. If \nthere are some missing data, they can be estimated. \nHowever, if most data are missing, calculated averages \ncan be misleading.  \nSummarising storage in lakes by country or basin is \nstraightforward in principle, as they can be added up. \nHowever, not all water bodies are measured all the \ntime, and gaps in the data need to be estimated.  \nSummarising river flows by country or catchment is \nchallenging. For example, many countries contain \nmultiple rivers. We selected the fifteen river \nobservation locations with the largest long-term \naverage flows within the country or catchment and \ncalculated a weighted average value. By its very nature, \naveraging over years and regions can hide locally'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='averaging over years and regions can hide locally \nsevere conditions or extreme events that occur over \nshort periods. This should be kept in mind when \ninterpreting the information. \nSatellite instruments can provide a near-immediate \nglobal overview of climate and water conditions, but \nthey have uncertainties. Where available, onsite \nobservations are usually more accurate and necessary \nto calibrate remote sensing approaches like those used \nhere. Protecting and expanding the remaining water \nmeasurement station network should be a priority.  \nRecord length, frequency and spatial detail vary \nbetween data sources. For example, climate data are \navailable from 1979, water body data from 1984, soil \nwater data from 1991, river flow data from 2000, and \nterrestrial water storage data from 2002 onwards.  \nEven satellite observations are unavailable in some \nregions and at some times. For example, soil water \nobservations are only possible if the soil is not frozen'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 8, 'page_label': '9'}, page_content='observations are only possible if the soil is not frozen \nor covered with dense forest, and surface water and \nvegetation observations require daylight and clear \nskies. In the case of climate data, data gaps are filled \nby weather models with uncertainties of their own.  \nEfforts were made to confirm the interpretation of the \ndata using background research, but the above \nlimitations should be kept in mind when reading this \nreport. Anyone inclined to take action based on the \ninformation presented here should first consult the \nrelevant local or national agencies.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 9, 'page_label': '10'}, page_content='10                 \n   |'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 10, 'page_label': '11'}, page_content='|  \n                     11 \n \n \n \n \nThe global land area average annual precipitation was \n798 mm, 11.6 mm higher than the baseline. There is a \nstatistically significant declining trend in global \nprecipitation of 0.65 mm per year (−0.08% annually \nrelative to the baseline). \n \n \nAverage annual precipitation over land. \nRecord-high monthly precipitation values were 27% \nhigher than for the baseline period, but there is no \nsignificant trend.  \nThe frequency of record-low monthly precipitation \nvalues in the 4,687 catchments worldwide was 38% \nhigher than the 1995–2005 average. There is a \nsignificant increasing trend of 3.8% per decade in \nrecord-low months.  \n \nThe number of times high monthly precipitation records were broken   \nrelative to the baseline period 1995–2005  \n \n \nThe number of times low monthly precipitation records were broken \nrelative to the baseline period 1995–2005'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 11, 'page_label': '12'}, page_content='12                 \n   |  \n  \n \nSeveral countries recorded their highest annual \nprecipitation totals since 1979. In West Africa, \nNiger and Mali broke records, while in Europe, \nDenmark, Luxembourg, and Monaco saw their \nhighest precipitation levels. India experienced \nrecord-high national rainfall, as did the \nSeychelles.  \nConversely, countries such as Zambia, \nZimbabwe, the DR Congo and the Central African \nRepublic in Africa, and Colombia in South \nAmerica, recorded their lowest precipitation \ntotals. \nRecord-high precipitation totals were observed \nin 16 river basins in 2024. Notable examples \ninclude the Niger and Chad Basins in Africa, the \nIndia Bengal Coast Basin, and the Sumatra Basin \nin Asia, as well as the Po-Adriatic Coast Basin in \nEurope. In North America, the Alaska Arctic \nCoast and Arctic Greenland Coast recorded \nsignificant precipitation increases. \nSeven river basins experienced record-low \nprecipitation, including the Congo and Zambezi'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 11, 'page_label': '12'}, page_content='Seven river basins experienced record-low \nprecipitation, including the Congo and Zambezi \nBasins in Africa, the Orinoco Basin and Colombia \nCaribbean Coast Basin in South America, and \nthe Don Basin and Crimea in Eastern Europe. \nThe Paraguay Basin also experienced unusually \nlow precipitation, though it remained higher than \nits 2020 levels. \n  \n \nStandardised anomaly in annual precipitation (see p.9 or p. 57 for legend) \n  \nBy country \n \nBy river basin'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 12, 'page_label': '13'}, page_content='|  \n                     13 \n \n \n \n \nThe highest daily maximum rainfall in 2024 − averaged \nover 4,687 catchments worldwide − was 7.8% higher \nthan for the 1995–2005 baseline period. There is no \nstatistically significant long-term trend. \n \nAnnual maximum 24h precipitation over land. \nThe frequency of record-high monthly values for daily \nmaximum rainfall was 52% above the 1995–2005 \naverage, and there is a significant trend in the number \nof record maximum rainfall of 4.1% per decade. \nResearch has found that increasing trends in extreme \nprecipitation over shorter periods (five days or less) \nhave become more common than decreasing trends8. \n \n8 Seneviratne et al. (2021) Weather and Climate Extreme Events in a \nChanging Climate. In: Climate Change 2021: The Physical Science \nBasis, pp. 1513-1766 (link) \nThis would be expected to increase the risk of local \nflash floods. \n \n \nThe number of months and catchments that maximum 24h'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 12, 'page_label': '13'}, page_content='flash floods. \n \n \nThe number of months and catchments that maximum 24h \nprecipitation records were broken in 4,687 catchments worldwide \nrelative to the average for the baseline period (1995–2005)'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 13, 'page_label': '14'}, page_content='14                 \n   |  \n  \n \nA total of 23 countries recorded their highest \nannual daily maximum rainfall in 2024. In West \nAfrica, Niger and Mali reported record-breaking \nvalues far exceeding records since 1979. In \nEurope, the United Kingdom, Slovakia, Norway \nand Luxembourg reached record highs, with \nBelgium and France also showing unusually high \nvalues.  \nIn Asia, India and Myanmar reported significant \nrecords, while China, Korea, and Mongolia also \nexperienced their highest single-day rainfall \ntotals. In Africa, Tanzania in Eastern Africa and \nChad in Central Africa were among the countries \nwith new records. \nRecord-breaking maximum daily rainfall totals \nwere recorded in 35 river basins worldwide. In \nWest Africa, the Niger Basin experienced some \nof the highest single-day rainfall events ever \nobserved. In South Asia, the Ganges-\nBrahmaputra Basin reached unprecedented daily \nrainfall totals, as did the Sumatra Basin and \nnearby basins in Indonesia.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 13, 'page_label': '14'}, page_content='rainfall totals, as did the Sumatra Basin and \nnearby basins in Indonesia. \nIn Europe, the Western Baltic Coast and England \nand Wales saw extreme rainfall events. Several \nArctic regions also recorded significant daily \nprecipitation peaks. \n \nStandardised anomaly in annual maximum 24h precipitation (see p.9 or p. 57 for \nlegend) \n  \nBy country \n \nBy river basin'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 14, 'page_label': '15'}, page_content='|  \n                     15 \n \n \n \n \nGlobally, 2024 was the hottest year on record over \nland. Air temperature across land was 1.2°C above the \n1995–2005 average. There has been a statistically \nsignificant increase of 0.35°C per decade. \n \n \nAnnual average temperature over the global land area.  \n \nThe number of record-high monthly average \ntemperatures in the 4,687 river catchments worldwide \nwas the highest in the 45-year record and 9.3 times the \n1995–2005 average. There has been a rapid increase \nin record-breaking high monthly temperatures of 97% \nper decade. \nThe number of record-low monthly average \ntemperatures was 85% less frequent than the baseline \naverage. There is a significant decreasing trend of \n−66% fewer record-breaking low monthly average \ntemperatures per decade. \n \nThe number of times high monthly average temperature records were \nbroken compared to the average for 1995–2005.  \n \nThe number of times low monthly temperature records were broken'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 14, 'page_label': '15'}, page_content='The number of times low monthly temperature records were broken \ncompared to the average for 1995–2005.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 15, 'page_label': '16'}, page_content='16                 \n   |  \n  \nNo countries recorded unusually low \nannual air temperatures in 2024, whereas \n111 countries recorded record-high \ntemperatures. They included 30 out of the \n54 countries in Africa, 24 out of 44 in \nEurope, 22 out of 49 in Asia, 26 out of 35 \nin South America, and 9 out of 14 in \nOceania. A further thirteen countries \nrecorded unusually high but not record \ntemperatures, including Canada.  \nNo river basins experienced unusually \nlow annual air temperatures in 2024, \nwhereas record-high temperatures were \nobserved in 111 out of 292 river basins \nglobally. They included the Amazonas \nand Orinoco basins in South America; the \nCongo, Niger, Nile, and Zambezi basins in \nAfrica; the Yangtze and Mekong in Asia \nand the Danube basin in Europe.  \nAnother thirty-four basins recorded \nunusually high but not record annual \ntemperatures, including the Orange and \nOkavango basins in Africa.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-01-04T20:51:43+10:00', 'author': 'Albert Van Dijk', 'moddate': '2025-01-04T20:51:43+10:00', 'source': 'data/pdf\\GlobalWaterMonitor-Report-2024.pdf', 'total_pages': 58, 'page': 15, 'page_label': '16'}, page_content='temperatures, including the Orange and \nOkavango basins in Africa.\n \n \n  \nStandardised anomaly in annual average air temperature (see p.9 or p. 57 for legend - \nnote the colour scale is reversed for temperature, with red showing higher \ntemperatures)  \n \nBy country \n \nBy river basin'),
# ...
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}, page_content="Zambia\nSierra Leone\nCôte d'Ivoire\nEswatini\nNamibia\nTogo\nCabo Verde\nUganda\nMalawi\nSenegal\nBenin\nKenya\nEthiopia\nBotswana\nMauritius\nMorocco\nNiger\nMali\nTanzania\nSeychelles\nFairly well/Very well Fairly badly/Very badly"),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content='Copyright ©Afrobarometer 2024  20 \n \nFigure 21: Government performance in providing water and sanitation services               \n| 30 countries | 2011-2023 \n \nRespondents were asked: How well or badly would you say the current government is handling the \nfollowing matters, or haven’t you heard enough to say: Providing water and sanitation services?  \nFigure 22: Increase in positive evaluations of government performance on providing \nwater and sanitation services | 11 countries | 2011-2023 \n \nRespondents were asked: How well or badly would you say the current government is handling the \nfollowing matters, or haven’t you heard enough to say: Providing water and sanitation services? (Figure \nshows change, in percentage points, between survey rounds in 2011/2013 and 2021/2023 in the \nproportion of respondents who say “fairly well” or “very well”) \n56% 53% 53%\n57% 60%\n40% 41% 44% 42% 40%\n0%\n20%\n40%\n60%\n80%\n100%\n2011/ 2013 2014/ 2015 2016/ 2018 2019/ 2021 2021/ 2023\nFairly badly/\nVery badly'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content='40%\n60%\n80%\n100%\n2011/ 2013 2014/ 2015 2016/ 2018 2019/ 2021 2021/ 2023\nFairly badly/\nVery badly\nFairly well/\nVery well\n34% 32% 28%\n40% 44% 38% 33% 32% 30% 22%\n42%\n64% 57%\n44%\n56% 59%\n48% 41% 38% 36%\n26%\n47%\n+31\n+25\n+17\n+16 +15\n+10\n+8 +6 +6\n+4\n+4\n0%\n20%\n40%\n60%\n80%\n2011/2013 2021/2023'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content='Copyright ©Afrobarometer 2024  21 \n \nFigure 23: Decrease in positive evaluations of government performance on providing \nwater and sanitation services | 12 countries | 2011-2023 \n  \nRespondents were asked: How well or badly would you say the current government is handling the \nfollowing matters, or haven’t you heard enough to say: Providing water and sanitation services? (Figure \nshows change, in percentage points, between survey rounds in 2011/2013 and 2021/2023 in the \nproportion of respondents who say “fairly well” or “very well”) \nConclusion  \nSurvey findings show that water supply and sanitation remain major challenges in most \nAfrican countries, especially for rural populations and poor households. Ensuring an \nadequate supply of clean water ranks high on citizens’ policy agenda as the share \nexperiencing water shortages inches upward. Climate change is likely to continue to \nheighten pressure for decisive action by African governments, which are widely seen as'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content='heighten pressure for decisive action by African governments, which are widely seen as \nfailing to provide their citizens the basic necessities of safe water and sanitation.  \n \n \n \n \n \n \n \n \n \n \n \n56%\n38%\n48%\n32%\n67%\n51%\n29%\n43%\n53%\n62%\n49%\n30%28%\n13%\n30%\n17%\n55%\n40%\n19%\n35%\n46%\n56%\n42%\n25%\n-28\n-25\n-18\n-15\n-12\n-11\n-10\n-9\n-8\n-6\n-6\n-5\n0%\n20%\n40%\n60%\n80%\n2011/2013 2021/2023'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content='Copyright ©Afrobarometer 2024  22 \n \nReferences  \nAfrican Union. (2015). Agenda 2063: The Africa we want. \nAfrican Union. (2023). Concrete actions towards water security in Africa brought forward as the \ncontinent prepares its water investment action plan. News release. 18 September.  \nMalpass, D., & Sall, M. (2022). A bold response is needed to achieve a water-secure
. \nStevenson Male Ssevume is a researcher for Hatchile Consult Ltd. in Uganda.                          \nEmail: stevenson@hatchileconsult.com                    \nAfrobarometer, a nonprofit corporation with headquarters in Ghana, is  a pan-African, non-\npartisan research network. Regional coordination of national partners in about 35 countries is \nprovided by the Ghana Center for Democratic Development (CDD-Ghana), the Institute for \nJustice and Reconciliation (IJR) in South Africa, and the Institute for Development Studies \n(IDS) at the University of Nairobi in Kenya. Michigan State University (MSU) and the University'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content='(IDS) at the University of Nairobi in Kenya. Michigan State University (MSU) and the University \nof Cape Town (UCT) provide technical support to the network. \nFinancial support for Afrobarometer is provided by Sweden via the Swedish International \nDevelopment Cooperation Agency, the U.S. Agency for International Development (USAID) \nvia the U.S. Institute of Peace, the Mo Ibrahim Foundation, the Open Society Foundations  - \nAfrica, Luminate, the William and Flora Hewlett Foundation, the Bill & Melinda Gates \nFoundation, the Mastercard Foundation, the David and Lucile Packard Foundation, the \nEuropean Union Commission, the World Bank Group, the Ministry of Foreign Affairs of Finland, \nthe Embassy of the Kingdom of the Netherlands in Uganda, the Embassy of Sweden in \nZimbabwe, the Global Centre for Pluralism, and GIZ. \nDonations help Afrobarometer give voice to African citizens. Please consider making a'),
#  Document(metadata={'producer': 'Adobe PDF Library 24.1.124', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2024-03-19T00:14:32-05:00', 'author': 'Brian Howard', 'comments': '', 'company': 'University of Cape Town', 'keywords': '', 'moddate': '2024-03-19T00:14:49-05:00', 'sourcemodified': '', 'subject': '', 'title': '', 'source': 'data/pdf\\Water-and-sanitation-major-challenges-Africa-march24.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content='Donations help Afrobarometer give voice to African citizens. Please consider making a \ncontribution (at www.afrobarometer.org) or contact Felix Biga (felixbiga@afrobarometer.org ) \nor Runyararo Munetsi (runyararo@afrobarometer.org) to discuss institutional funding. \nFor more information, please visit www.afrobarometer.org. \nFollow our releases on #VoicesAfrica.  \n                             /Afrobarometer                  @Afrobarometer                          \nAfrobarometer Dispatch No. 784 | 19 March 2024')]

# %%
import pandas as pd
from langchain.schema import Document

# Load the CSV file
csv_file_path = "data/csv/water_usage_data.csv"
water_data = pd.read_csv(csv_file_path)


def load_water_usage_data():
    # Process the data and fill in placeholders
    documents = []
    for index, row in water_data.iterrows():
        district = row['District']
        crop = row['Crop']
        irrigation_method = row['Irrigation Method']
        water_consumption = row['Water Consumption (liters/hectare)']
        water_availability = row['Water Availability (liters/hectare)']
        content = f"In the district {district}, the crop {crop} is cultivated using the {irrigation_method} method. The water consumption for this irrigation method is approximately {water_consumption}, while the water availability in the region is around {water_availability}. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system."
        documents.append(Document(page_content=content, metadata={"index": index}))
    return documents


water_usage_csv = load_water_usage_data()
water_usage_csv
# Out:
# [Document(metadata={'index': 0}, page_content='In the district Udaipur, the crop Garlic is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11609.330885810616, while the water availability in the region is around 11335.919980150127. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 1}, page_content='In the district Bhilwara, the crop Gram is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 12648.406038302792, while the water availability in the region is around 12091.900253943171. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 2}, page_content='In the district Udaipur, the crop Guava is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 10063.162447916591, while the water availability in the region is around 9810.943168837392. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 3}, page_content='In the district Jodhpur, the crop Barley is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 10110.539993326256, while the water availability in the region is around 10754.217313163708. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 4}, page_content='In the district Alwar, the crop Gram is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 9320.45101775053, while the water availability in the region is around 8695.537818813737. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 5}, page_content='In the district Alwar, the crop Bajra is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 13707.248507009224, while the water availability in the region is around 13088.40603512336. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 6}, page_content='In the district Udaipur, the crop Gram is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 6419.276991936418, while the water availability in the region is around 6685.757927114612. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 7}, page_content='In the district Nagaur, the crop Gram is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 9289.883923057483, while the water availability in the region is around 9468.516256279372. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 8}, page_content='In the district Hanumangarh, the crop Pulses is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 6437.159656087371, while the water availability in the region is around 6909.587516713526. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 9}, page_content='In the district Hanumangarh, the crop Citrus is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 15661.876221224187, while the water availability in the region is around 16224.039215387857. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 10}, page_content='In the district Kota, the crop Opium is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 10553.033527645484, while the water availability in the region is around 9809.797091748638. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 11}, page_content='In the district Alwar, the crop Fenugreek is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 9733.308655797786, while the water availability in the region is around 9502.633933285197. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 12}, page_content='In the district Nagaur, the crop Opium is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 7811.486749531211, while the water availability in the region is around 8738.673824890717. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 13}, page_content='In the district Sri Ganganagar, the crop Tomato is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 6562.789955907221, while the water availability in the region is around 6767.8388552599845. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 14}, page_content='In the district Hanumangarh, the crop Sugarcane is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 13435.987795036868, while the water availability in the region is around 14307.01194996194. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 15}, page_content='In the district Ajmer, the crop Bajra is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11392.330625198285, while the water availability in the region is around 10973.489616156785. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 16}, page_content='In the district Udaipur, the crop Fenugreek is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 14439.690538574308, while the water availability in the region is around 14739.863314188262. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 17}, page_content='In the district Kota, the crop Chilli is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 9909.752939787137, while the water availability in the region is around 10431.30298945327. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 18}, page_content='In the district Hanumangarh, the crop Onion is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12835.02600869453, while the water availability in the region is around 13622.75801145037. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 19}, page_content='In the district Hanumangarh, the crop Sugarcane is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11629.659341985467, while the water availability in the region is around 11675.119314403872. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 20}, page_content='In the district Jaipur, the crop Pomegranate is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 6516.406866225762, while the water availability in the region is around 5629.616414816876. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 21}, page_content='In the district Sri Ganganagar, the crop Oilseeds is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 12487.54016587375, while the water availability in the region is around 11780.396946155142. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 22}, page_content='In the district Jaipur, the crop Opium is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 8902.221311781012, while the water availability in the region is around 8984.565486647485. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 23}, page_content='In the district Udaipur, the crop Tomato is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 10033.949035638458, while the water availability in the region is around 10385.001062677577. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 24}, page_content='In the district Hanumangarh, the crop Maize is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 5680.971783779863, while the water availability in the region is around 6249.586129521636. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 25}, page_content='In the district Sri Ganganagar, the crop Opium is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 14601.97345705037, while the water availability in the region is around 14377.082754334351. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 26}, page_content='In the district Udaipur, the crop Garlic is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 7218.003497841976, while the water availability in the region is around 6720.685754586588. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 27}, page_content='In the district Nagaur, the crop Tomato is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 15963.099655793849, while the water availability in the region is around 16372.357793579424. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 28}, page_content='In the district Udaipur, the crop Cumin is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13257.570180740451, while the water availability in the region is around 14186.149826992512. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 29}, page_content='In the district Sri Ganganagar, the crop Tomato is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 14120.947084017454, while the water availability in the region is around 13269.88507210464. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 30}, page_content='In the district Kota, the crop Chilli is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 10153.058292675343, while the water availability in the region is around 10010.073921476813. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 31}, page_content='In the district Hanumangarh, the crop Cotton is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 6723.227424893816, while the water availability in the region is around 7415.255817074856. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 32}, page_content='In the district Jaipur, the crop Mango is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12977.27773757686, while the water availability in the region is around 12286.889133173432. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 33}, page_content='In the district Kota, the crop Mango is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 13618.186915349524, while the water availability in the region is around 13868.92024046748. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 34}, page_content='In the district Sri Ganganagar, the crop Onion is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 7361.595151100787, while the water availability in the region is around 7776.958273889738. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 35}, page_content='In the district Hanumangarh, the crop Maize is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13634.279339771629, while the water availability in the region is around 14206.795818446342. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 36}, page_content='In the district Kota, the crop Citrus is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 7095.432378887967, while the water availability in the region is around 6537.828541090872. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 37}, page_content='In the district Ajmer, the crop Fenugreek is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 8522.56991173552, while the water availability in the region is around 8109.718626075927. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 38}, page_content='In the district Nagaur, the crop Chilli is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 14931.395817121758, while the water availability in the region is around 15578.772618972163. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 39}, page_content='In the district Jaipur, the crop Gram is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 8239.982405328281, while the water availability in the region is around 9048.975322303666. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 40}, page_content='In the district Nagaur, the crop Coriander is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13613.70107747452, while the water availability in the region is around 13978.803799011575. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 41}, page_content='In the district Udaipur, the crop Pomegranate is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 9085.174931130705, while the water availability in the region is around 9165.649557015828. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 42}, page_content='In the district Sri Ganganagar, the crop Wheat is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 10071.739448849285, while the water availability in the region is around 10089.210634854711. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 43}, page_content='In the district Bhilwara, the crop Barley is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 14299.119224990502, while the water availability in the region is around 13684.144000857856. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 44}, page_content='In the district Hanumangarh, the crop Mustard is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 6889.199378585089, while the water availability in the region is around 7801.751791531888. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 45}, page_content='In the district Hanumangarh, the crop Garlic is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 12947.546168249088, while the water availability in the region is around 12369.109118120135. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 46}, page_content='In the district Ajmer, the crop Fenugreek is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 13521.265671888106, while the water availability in the region is around 12932.424807851938. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 47}, page_content='In the district Alwar, the crop Fennel is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 12710.18554630436, while the water availability in the region is around 12017.69470073965. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 48}, page_content='In the district Bhilwara, the crop Opium is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 6133.059552617516, while the water availability in the region is around 5279.555610936549. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 49}, page_content='In the district Kota, the crop Cotton is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 11348.080971156303, while the water availability in the region is around 10803.372241039617. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 50}, page_content='In the district Sri Ganganagar, the crop Citrus is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 10890.190634568977, while the water availability in the region is around 10699.086675977527. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 51}, page_content='In the district Udaipur, the crop Wheat is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11013.95655402179, while the water availability in the region is around 11083.625294143794. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 52}, page_content='In the district Nagaur, the crop Mustard is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 11497.93256942712, while the water availability in the region is around 10643.111459025076. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 53}, page_content='In the district Hanumangarh, the crop Gram is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 12684.691865658902, while the water availability in the region is around 12287.393285348644. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 54}, page_content='In the district Jodhpur, the crop Sugarcane is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 8163.199520499352, while the water availability in the region is around 8807.44426081746. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 55}, page_content='In the district Jaipur, the crop Onion is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 9916.312265891533, while the water availability in the region is around 9189.075186550626. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 56}, page_content='In the district Alwar, the crop Garlic is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 13943.963481004028, while the water availability in the region is around 13232.114555920994. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 57}, page_content='In the district Udaipur, the crop Wheat is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 7730.729879518505, while the water availability in the region is around 6740.789557666515. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 58}, page_content='In the district Nagaur, the crop Pomegranate is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 8971.757271053142, while the water availability in the region is around 9468.350444518728. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 59}, page_content='In the district Udaipur, the crop Bajra is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 14424.594625033218, while the water availability in the region is around 15127.51232771632. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 60}, page_content='In the district Kota, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 8666.711731395135, while the water availability in the region is around 9336.20846513126. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 61}, page_content='In the district Ajmer, the crop Gram is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11873.42203702272, while the water availability in the region is around 12008.00732596832. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 62}, page_content='In the district Jaipur, the crop Garlic is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12262.89999826493, while the water availability in the region is around 11409.18914258203. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 63}, page_content='In the district Jodhpur, the crop Cotton is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 7696.485269314778, while the water availability in the region is around 7857.676576132166. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 64}, page_content='In the district Udaipur, the crop Guava is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 12361.200413289487, while the water availability in the region is around 11830.26611078133. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 65}, page_content='In the district Sri Ganganagar, the crop Coriander is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 13279.315411497582, while the water availability in the region is around 12914.887285965033. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 66}, page_content='In the district Bhilwara, the crop Mango is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 9255.73704320351, while the water availability in the region is around 8560.526967311776. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 67}, page_content='In the district Nagaur, the crop Guava is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 14431.507674880544, while the water availability in the region is around 13768.786696692505. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 68}, page_content='In the district Udaipur, the crop Maize is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 14175.39300940438, while the water availability in the region is around 14457.070098084112. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 69}, page_content='In the district Sri Ganganagar, the crop Guava is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13238.444726642763, while the water availability in the region is around 12901.570627237445. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 70}, page_content='In the district Bhilwara, the crop Tomato is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 10119.608326045878, while the water availability in the region is around 9730.551918936548. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 71}, page_content='In the district Hanumangarh, the crop Gram is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13269.83042310602, while the water availability in the region is around 12433.77780927833. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 72}, page_content='In the district Sri Ganganagar, the crop Pulses is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 8443.310384900395, while the water availability in the region is around 9215.982049058186. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 73}, page_content='In the district Jodhpur, the crop Mustard is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 13915.548102979274, while the water availability in the region is around 14178.801091901783. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 74}, page_content='In the district Nagaur, the crop Cumin is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12124.622960993804, while the water availability in the region is around 11550.1443333464. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 75}, page_content='In the district Jaipur, the crop Garlic is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 10546.981890410336, while the water availability in the region is around 11544.43824043404. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 76}, page_content='In the district Bhilwara, the crop Fennel is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 9864.564863409383, while the water availability in the region is around 9311.178158658093. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 77}, page_content='In the district Nagaur, the crop Sugarcane is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11408.142767529587, while the water availability in the region is around 11428.96675421716. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 78}, page_content='In the district Alwar, the crop Guava is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 11797.271396413676, while the water availability in the region is around 12493.23507662141. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 79}, page_content='In the district Nagaur, the crop Fenugreek is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 12237.943642439866, while the water availability in the region is around 11518.68502775404. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 80}, page_content='In the district Kota, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 12623.944736670115, while the water availability in the region is around 12590.951568124978. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 81}, page_content='In the district Udaipur, the crop Barley is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13625.997549273045, while the water availability in the region is around 13089.497364481676. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 82}, page_content='In the district Sri Ganganagar, the crop Guava is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 5463.334821739253, while the water availability in the region is around 4876.882971174255. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 83}, page_content='In the district Udaipur, the crop Pomegranate is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 10986.5068597392, while the water availability in the region is around 11749.610822375753. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 84}, page_content='In the district Jaipur, the crop Fennel is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 6547.55675032349, while the water availability in the region is around 7484.439551995902. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 85}, page_content='In the district Sri Ganganagar, the crop Cotton is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 8243.694955155122, while the water availability in the region is around 8000.731989268779. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 86}, page_content='In the district Nagaur, the crop Fennel is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 10108.79849120498, while the water availability in the region is around 9861.456053292071. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 87}, page_content='In the district Ajmer, the crop Chilli is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 9040.477636459944, while the water availability in the region is around 9775.91648020244. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 88}, page_content='In the district Bhilwara, the crop Onion is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 10039.872681502624, while the water availability in the region is around 9317.809295656883. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 89}, page_content='In the district Kota, the crop Maize is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 12174.971023916056, while the water availability in the region is around 11736.590040615803. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 90}, page_content='In the district Kota, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 9562.57236227422, while the water availability in the region is around 9997.17777918241. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 91}, page_content='In the district Jodhpur, the crop Fenugreek is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 10023.930484985807, while the water availability in the region is around 9684.38001547191. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 92}, page_content='In the district Jodhpur, the crop Onion is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 10952.760107700857, while the water availability in the region is around 11134.34190531922. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 93}, page_content='In the district Alwar, the crop Wheat is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 5660.778337315934, while the water availability in the region is around 5807.75136002047. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 94}, page_content='In the district Kota, the crop Pulses is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 15473.720640240846, while the water availability in the region is around 14767.450840411006. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 95}, page_content='In the district Kota, the crop Cotton is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 10569.079039696418, while the water availability in the region is around 10379.991672629045. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 96}, page_content='In the district Nagaur, the crop Fennel is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 14838.990137550123, while the water availability in the region is around 15294.938768445518. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 97}, page_content='In the district Sri Ganganagar, the crop Mustard is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 8966.382229719027, while the water availability in the region is around 9951.933877134985. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 98}, page_content='In the district Bhilwara, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11379.8506978694, while the water availability in the region is around 11581.5281266918. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 99}, page_content='In the district Nagaur, the crop Oilseeds is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 8123.689169801193, while the water availability in the region is around 8494.87149740953. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 100}, page_content='In the district Bhilwara, the crop Coriander is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 8372.023489117902, while the water availability in the region is around 8142.947254601598. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
# ...
#  Document(metadata={'index': 967}, page_content='In the district Kota, the crop Bajra is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 6436.522126594041, while the water availability in the region is around 6621.78342901822. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 968}, page_content='In the district Ajmer, the crop Maize is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 8045.384111521924, while the water availability in the region is around 7979.532606592008. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 969}, page_content='In the district Kota, the crop Bajra is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 10081.243355329048, while the water availability in the region is around 10292.945825050028. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 970}, page_content='In the district Sri Ganganagar, the crop Sugarcane is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11896.694664139975, while the water availability in the region is around 11299.496673601214. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 971}, page_content='In the district Bhilwara, the crop Mustard is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 9518.420014325224, while the water availability in the region is around 8853.95209054564. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 972}, page_content='In the district Bhilwara, the crop Citrus is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11085.604097247267, while the water availability in the region is around 11724.811713006602. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 973}, page_content='In the district Bhilwara, the crop Wheat is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 11803.361919248924, while the water availability in the region is around 10969.827630229493. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 974}, page_content='In the district Sri Ganganagar, the crop Coriander is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11975.95081041919, while the water availability in the region is around 11327.349446183489. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 975}, page_content='In the district Alwar, the crop Tomato is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 10189.053450926966, while the water availability in the region is around 9939.347220795313. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 976}, page_content='In the district Nagaur, the crop Onion is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 10136.330451762096, while the water availability in the region is around 10566.057193512012. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 977}, page_content='In the district Ajmer, the crop Pulses is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 5526.651109413838, while the water availability in the region is around 6249.9613639384825. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 978}, page_content='In the district Udaipur, the crop Onion is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 15110.09187606618, while the water availability in the region is around 15990.661846594212. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 979}, page_content='In the district Udaipur, the crop Pomegranate is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 8945.537122045691, while the water availability in the region is around 9920.581247190008. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 980}, page_content='In the district Jodhpur, the crop Citrus is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 15326.493667644345, while the water availability in the region is around 14575.448684746496. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 981}, page_content='In the district Nagaur, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 14503.638674506625, while the water availability in the region is around 15417.832427738063. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 982}, page_content='In the district Udaipur, the crop Chilli is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12572.918849619173, while the water availability in the region is around 12309.279931464564. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 983}, page_content='In the district Jaipur, the crop Fennel is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 14752.660104771234, while the water availability in the region is around 15223.988515974735. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 984}, page_content='In the district Ajmer, the crop Onion is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 11927.850412717902, while the water availability in the region is around 11650.678989147877. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 985}, page_content='In the district Jaipur, the crop Opium is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 7550.14789705273, while the water availability in the region is around 7461.089437417133. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 986}, page_content='In the district Kota, the crop Cotton is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 11279.218390687633, while the water availability in the region is around 12182.774881564972. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 987}, page_content='In the district Kota, the crop Wheat is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 13059.561847404677, while the water availability in the region is around 13348.356628845317. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 988}, page_content='In the district Alwar, the crop Pomegranate is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 9461.263911372687, while the water availability in the region is around 8838.910415357706. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 989}, page_content='In the district Alwar, the crop Oilseeds is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 10271.70641824336, while the water availability in the region is around 9876.145550168569. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 990}, page_content='In the district Hanumangarh, the crop Fenugreek is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12984.409466095063, while the water availability in the region is around 13452.2763400092. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 991}, page_content='In the district Jodhpur, the crop Gram is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 14130.558635223928, while the water availability in the region is around 13668.601310908767. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 992}, page_content='In the district Ajmer, the crop Pomegranate is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 6101.421126525872, while the water availability in the region is around 5438.218510197712. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 993}, page_content='In the district Bhilwara, the crop Wheat is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 6487.909180173512, while the water availability in the region is around 6880.5425947078365. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 994}, page_content='In the district Hanumangarh, the crop Citrus is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 11398.212254415364, while the water availability in the region is around 10739.480766670336. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 995}, page_content='In the district Udaipur, the crop Oilseeds is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 7842.481531152681, while the water availability in the region is around 7206.450194109242. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 996}, page_content='In the district Jodhpur, the crop Tomato is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 7868.457709436712, while the water availability in the region is around 6986.421839330428. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 997}, page_content='In the district Kota, the crop Bajra is cultivated using the Canal Irrigation method. The water consumption for this irrigation method is approximately 13002.941293250622, while the water availability in the region is around 13746.172387265153. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 998}, page_content='In the district Bhilwara, the crop Fennel is cultivated using the Drip Irrigation method. The water consumption for this irrigation method is approximately 14276.93126698208, while the water availability in the region is around 13609.183532194167. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.'),
#  Document(metadata={'index': 999}, page_content='In the district Sri Ganganagar, the crop Mustard is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 7011.556633995436, while the water availability in the region is around 6140.081508774301. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.')]

# %%
import pandas as pd
from langchain.schema import Document

# Load the CSV file
csv_file_path = "data/csv/scarcity.csv"
water_data = pd.read_csv(csv_file_path, delimiter=';')


def load_water_usage_data():
    # Process the data and fill in placeholders
    documents = []
    for index, row in water_data.iterrows():
        # Extract all the columns from the current row
        basin_id = row['basin_id']
        basin_name = row['basin_name']
        population = row['population']
        jan = row['jan']
        feb = row['feb']
        mar = row['mar']
        apr = row['apr']
        may = row['may']
        jun = row['jun']
        jul = row['jul']
        aug = row['aug']
        sep = row['sep']
        oct_ = row['oct']  # `oct` is Python reserved keyword, so use `oct_` to avoid conflicts
        nov = row['nov']
        dec = row['dec']
        average = row['average']
        low = row['low']
        moderate = row['moderate']
        significant = row['significant']
        severe = row['severe']
        content = f"The basin {basin_name} (ID: {basin_id}) supports a population of {population}. The water scarcity levels recorded for each month are: January ({jan}), February ({feb}), March ({mar}), April ({apr}), May ({may}), June ({jun}), July ({jul}), August ({aug}), September ({sep}), October ({oct}), November ({nov}), and December ({dec}). The average water scarcity level for this basin is {average}, with {low} months of low scarcity, {moderate} months of moderate scarcity, {significant} months of significant scarcity, and {severe} months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. "
        documents.append(Document(page_content=content, metadata={"index": index, "basin_name": basin_name}))
    return documents


water_scarcity_csv = load_water_usage_data()
water_scarcity_csv
# Out:
# [Document(metadata={'index': 0, 'basin_name': 'Khatanga'}, page_content='The basin Khatanga (ID: 1) supports a population of 4633. The water scarcity levels recorded for each month are: January (0,0028), February (0,0748), March (0,1238), April (0,2050), May (0,0198), June (0,0002), July (0,0003), August (0,0006), September (0,0010), October (<built-in function oct>), November (0,0030), and December (0,0050). The average water scarcity level for this basin is 0,0365, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 1, 'basin_name': 'Olenek'}, page_content='The basin Olenek (ID: 2) supports a population of 5960. The water scarcity levels recorded for each month are: January (0,0046), February (0,0353), March (0,0585), April (0,0968), May (0,0086), June (0,0003), July (0,0010), August (0,0018), September (0,0030), October (<built-in function oct>), November (0,0084), and December (0,0140). The average water scarcity level for this basin is 0,0198, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 2, 'basin_name': 'Anabar'}, page_content='The basin Anabar (ID: 3) supports a population of 1402. The water scarcity levels recorded for each month are: January (0,0025), February (0,0155), March (0,0257), April (0,0425), May (0,0704), June (0,0003), July (0,0006), August (0,0013), September (0,0022), October (<built-in function oct>), November (0,0062), and December (0,0102). The average water scarcity level for this basin is 0,0151, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 3, 'basin_name': 'Yana'}, page_content='The basin Yana (ID: 4) supports a population of 24517. The water scarcity levels recorded for each month are: January (0,0259), February (0,3188), March (0,5276), April (0,8731), May (0,1459), June (0,0031), July (0,0034), August (0,0061), September (0,0127), October (<built-in function oct>), November (0,0347), and December (0,0575). The average water scarcity level for this basin is 0,1691, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 4, 'basin_name': 'Yenisei'}, page_content='The basin Yenisei (ID: 5) supports a population of 8453280. The water scarcity levels recorded for each month are: January (0,4340), February (9,4345), March (15,4851), April (1,4567), May (0,2070), June (0,2701), July (0,4066), August (0,4410), September (0,3377), October (<built-in function oct>), November (0,4938), and December (0,8021). The average water scarcity level for this basin is 2,5119, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 5, 'basin_name': 'Indigirka'}, page_content='The basin Indigirka (ID: 6) supports a population of 41777. The water scarcity levels recorded for each month are: January (0,0208), February (0,2202), March (0,3645), April (0,6032), May (0,0877), June (0,0024), July (0,0027), August (0,0058), September (0,0109), October (<built-in function oct>), November (0,0301), and December (0,0498). The average water scarcity level for this basin is 0,1180, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 6, 'basin_name': 'Lena'}, page_content='The basin Lena (ID: 7) supports a population of 1284810. The water scarcity levels recorded for each month are: January (0,0771), February (1,8572), March (3,0693), April (3,3623), May (0,0140), June (0,0098), July (0,0145), August (0,0196), September (0,0228), October (<built-in function oct>), November (0,0845), and December (0,1400). The average water scarcity level for this basin is 0,7268, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 7, 'basin_name': 'Omoloy'}, page_content='The basin Omoloy (ID: 8) supports a population of 2881. The water scarcity levels recorded for each month are: January (0,1015), February (4,0716), March (6,7148), April (11,0455), May (18,0938), June (0,0064), July (0,0098), August (0,0212), September (0,0371), October (<built-in function oct>), November (0,1034), and December (0,1712). The average water scarcity level for this basin is 3,3699, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 8, 'basin_name': 'Tana (NO. FI)'}, page_content='The basin Tana (NO. FI) (ID: 9) supports a population of 6523. The water scarcity levels recorded for each month are: January (0,1020), February (675,0062), March (675,2675), April (675,4256), May (0,0026), June (0,0094), July (0,0160), August (0,0265), September (0,0337), October (<built-in function oct>), November (0,0940), and December (0,1556). The average water scarcity level for this basin is 168,85, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 9, 'basin_name': 'Colville'}, page_content='The basin Colville (ID: 10) supports a population of 980. The water scarcity levels recorded for each month are: January (0,0134), February (1,8170), March (3,0031), April (4,9577), May (0,0546), June (0,0013), July (0,0013), August (0,0024), September (0,0043), October (<built-in function oct>), November (0,0127), and December (0,0210). The average water scarcity level for this basin is 0,8247, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 10, 'basin_name': 'Alazeya'}, page_content='The basin Alazeya (ID: 11) supports a population of 6649. The water scarcity levels recorded for each month are: January (0,0342), February (0,2015), March (0,3336), April (0,5521), May (0,9136), June (0,0033), July (0,0113), August (0,0200), September (0,0332), October (<built-in function oct>), November (0,0909), and December (0,1506). The average water scarcity level for this basin is 0,1999, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 11, 'basin_name': 'Anderson'}, page_content='The basin Anderson (ID: 12) supports a population of 90. The water scarcity levels recorded for each month are: January (0,0055), February (0,8612), March (1,4246), April (2,3554), May (0,0001), June (0,0004), July (0,0007), August (0,0011), September (0,0019), October (<built-in function oct>), November (0,0052), and December (0,0086). The average water scarcity level for this basin is 0,3890, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 12, 'basin_name': 'Kolyma'}, page_content='The basin Kolyma (ID: 13) supports a population of 138225. The water scarcity levels recorded for each month are: January (0,0352), February (0,8134), March (1,3456), April (2,2250), May (0,0245), June (0,0051), July (0,0036), August (0,0082), September (0,0125), October (<built-in function oct>), November (0,0389), and December (0,0643). The average water scarcity level for this basin is 0,3833, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 13, 'basin_name': 'Tuloma'}, page_content='The basin Tuloma (ID: 14) supports a population of 209338. The water scarcity levels recorded for each month are: January (2,1008), February (17,0752), March (27,8103), April (44,8351), May (0,1147), June (0,3631), July (0,6625), August (1,1014), September (1,6666), October (<built-in function oct>), November (3,5976), and December (5,9357). The average water scarcity level for this basin is 8,9085, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 14, 'basin_name': 'Muonio'}, page_content='The basin Muonio (ID: 15) supports a population of 57777. The water scarcity levels recorded for each month are: January (0,3821), February (4,1849), March (6,9009), April (0,2570), May (0,0274), June (0,0495), July (0,0733), August (0,1416), September (0,1864), October (<built-in function oct>), November (0,5410), and December (0,8952). The average water scarcity level for this basin is 1,1611, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 15, 'basin_name': 'Yukon '}, page_content='The basin Yukon  (ID: 16) supports a population of 130852. The water scarcity levels recorded for each month are: January (0,0732), February (1,4055), March (2,3239), April (0,3885), May (0,0081), June (0,0089), July (0,0138), August (0,0228), September (0,0291), October (<built-in function oct>), November (0,0846), and December (0,1396). The average water scarcity level for this basin is 0,3788, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 16, 'basin_name': 'Palyavaam'}, page_content='The basin Palyavaam (ID: 17) supports a population of 7831. The water scarcity levels recorded for each month are: January (0,0697), February (623,8062), March (643,3724), April (655,8221), May (663,5607), June (0,0039), July (0,0072), August (0,0141), September (0,0209), October (<built-in function oct>), November (0,0642), and December (0,1064). The average water scarcity level for this basin is 215,57, with 8 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 4 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 17, 'basin_name': 'Kemijoki'}, page_content='The basin Kemijoki (ID: 18) supports a population of 148981. The water scarcity levels recorded for each month are: January (0,3310), February (50,0359), March (79,0074), April (0,2714), May (0,0179), June (0,0659), July (0,1106), August (0,1725), September (0,1490), October (<built-in function oct>), November (0,3123), and December (0,5168). The average water scarcity level for this basin is 10,926, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 18, 'basin_name': 'Mackenzie '}, page_content='The basin Mackenzie  (ID: 19) supports a population of 494118. The water scarcity levels recorded for each month are: January (0,2929), February (18,9941), March (30,8799), April (0,1944), May (0,0244), June (0,0237), July (0,0397), August (0,0741), September (0,1116), October (<built-in function oct>), November (0,2882), and December (0,4740). The average water scarcity level for this basin is 4,2967, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 19, 'basin_name': 'Noatak '}, page_content='The basin Noatak  (ID: 20) supports a population of 2044. The water scarcity levels recorded for each month are: January (0,0331), February (6,2836), March (10,3406), April (16,9507), May (0,0129), June (0,0026), July (0,0047), August (0,0083), September (0,0082), October (<built-in function oct>), November (0,0311), and December (0,0514). The average water scarcity level for this basin is 2,8122, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 20, 'basin_name': 'Anadyr'}, page_content='The basin Anadyr (ID: 21) supports a population of 11240. The water scarcity levels recorded for each month are: January (0,0090), February (8,3700), March (13,7465), April (22,4602), May (0,0043), June (0,0005), July (0,0010), August (0,0019), September (0,0026), October (<built-in function oct>), November (0,0083), and December (0,0138). The average water scarcity level for this basin is 3,7186, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 21, 'basin_name': 'Pechora'}, page_content='The basin Pechora (ID: 22) supports a population of 605994. The water scarcity levels recorded for each month are: January (0,2334), February (18,4129), March (29,9508), April (0,3960), May (0,0098), June (0,0148), July (0,0353), August (0,0596), September (0,0730), October (<built-in function oct>), November (0,2257), and December (0,3736). The average water scarcity level for this basin is 4,1595, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 22, 'basin_name': 'Lule'}, page_content='The basin Lule (ID: 23) supports a population of 35562. The water scarcity levels recorded for each month are: January (0,1025), February (32,5938), March (52,3104), April (0,0287), May (0,0083), June (0,0085), July (0,0169), August (0,0289), September (0,0337), October (<built-in function oct>), November (0,0956), and December (0,1582). The average water scarcity level for this basin is 7,1194, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 23, 'basin_name': 'Kalixaelven'}, page_content='The basin Kalixaelven (ID: 24) supports a population of 35032. The water scarcity levels recorded for each month are: January (0,3964), February (4,7001), March (7,7466), April (0,0799), May (0,0251), June (0,0410), July (0,0883), August (0,1529), September (0,2255), October (<built-in function oct>), November (0,5390), and December (0,8919). The average water scarcity level for this basin is 1,2624, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 24, 'basin_name': 'Ob'}, page_content='The basin Ob (ID: 25) supports a population of 29372200. The water scarcity levels recorded for each month are: January (4,0137), February (140,4324), March (204,6547), April (0,5929), May (1,0247), June (2,9250), July (7,2572), August (9,7862), September (6,6400), October (<built-in function oct>), November (4,1680), and December (6,6834). The average water scarcity level for this basin is 32,653, with 10 months of low scarcity, 1 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 25, 'basin_name': 'Ellice'}, page_content='The basin Ellice (ID: 26) supports a population of 0. The water scarcity levels recorded for each month are: January (0,0000), February (0,0000), March (0,0000), April (0,0000), May (0,0000), June (0,0000), July (0,0000), August (0,0000), September (0,0000), October (<built-in function oct>), November (0,0000), and December (0,0000). The average water scarcity level for this basin is 0,0000, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 26, 'basin_name': 'Taz'}, page_content='The basin Taz (ID: 27) supports a population of 15085. The water scarcity levels recorded for each month are: January (0,0144), February (2,3835), March (3,9372), April (6,4939), May (0,0011), June (0,0006), July (0,0020), August (0,0033), September (0,0045), October (<built-in function oct>), November (0,0136), and December (0,0225). The average water scarcity level for this basin is 1,0737, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 27, 'basin_name': 'Kobuk '}, page_content='The basin Kobuk  (ID: 28) supports a population of 2198. The water scarcity levels recorded for each month are: January (0,0264), February (0,1753), March (0,2902), April (0,4803), May (0,0027), June (0,0051), July (0,0090), August (0,0149), September (0,0164), October (<built-in function oct>), November (0,0578), and December (0,0956). The average water scarcity level for this basin is 0,1007, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 28, 'basin_name': 'Coppermine'}, page_content='The basin Coppermine (ID: 29) supports a population of 431. The water scarcity levels recorded for each month are: January (0,0499), February (11,7395), March (19,2179), April (31,2356), May (0,0037), June (0,0020), July (0,0058), August (0,0103), September (0,0171), October (<built-in function oct>), November (0,0468), and December (0,0774). The average water scarcity level for this basin is 5,2028, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 29, 'basin_name': 'Hayes(Trib. Arctic Ocean)'}, page_content='The basin Hayes(Trib. Arctic Ocean) (ID: 30) supports a population of 0. The water scarcity levels recorded for each month are: January (0,0000), February (0,0000), March (0,0000), April (0,0000), May (0,0000), June (0,0000), July (0,0000), August (0,0000), September (0,0000), October (<built-in function oct>), November (0,0000), and December (0,0000). The average water scarcity level for this basin is 0,0000, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 30, 'basin_name': 'Pur'}, page_content='The basin Pur (ID: 31) supports a population of 196795. The water scarcity levels recorded for each month are: January (0,2516), February (675,6757), March (675,6757), April (675,6757), May (0,0259), June (0,0123), July (0,0404), August (0,0667), September (0,0643), October (<built-in function oct>), November (0,2318), and December (0,3836). The average water scarcity level for this basin is 169,02, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 31, 'basin_name': 'Varzuga'}, page_content='The basin Varzuga (ID: 32) supports a population of 4145. The water scarcity levels recorded for each month are: January (0,0832), February (675,6757), March (675,6757), April (675,6757), May (0,0057), June (0,0208), July (0,0356), August (0,0589), September (0,0349), October (<built-in function oct>), November (0,0766), and December (0,1269). The average water scarcity level for this basin is 168,96, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 32, 'basin_name': 'Ponoy'}, page_content='The basin Ponoy (ID: 33) supports a population of 3407. The water scarcity levels recorded for each month are: January (0,0254), February (675,6757), March (675,6757), April (675,6757), May (0,0020), June (0,0074), July (0,0126), August (0,0181), September (0,0120), October (<built-in function oct>), November (0,0234), and December (0,0387). The average water scarcity level for this basin is 168,93, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 33, 'basin_name': 'Kovda'}, page_content='The basin Kovda (ID: 34) supports a population of 33176. The water scarcity levels recorded for each month are: January (1,0261), February (675,6757), March (675,6757), April (675,6757), May (0,0356), June (0,1121), July (0,2062), August (0,3396), September (0,4410), October (<built-in function oct>), November (0,9453), and December (1,5637). The average water scarcity level for this basin is 169,34, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 34, 'basin_name': 'Back'}, page_content='The basin Back (ID: 35) supports a population of 11. The water scarcity levels recorded for each month are: January (0,0001), February (675,6757), March (675,6757), April (675,6757), May (0,0000), June (0,0000), July (0,0000), August (0,0000), September (0,0000), October (<built-in function oct>), November (0,0001), and December (0,0002). The average water scarcity level for this basin is 168,92, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 35, 'basin_name': 'Kem'}, page_content='The basin Kem (ID: 36) supports a population of 75620. The water scarcity levels recorded for each month are: January (0,3140), February (135,2620), March (197,9660), April (0,0280), May (0,0189), June (0,0546), July (0,0945), August (0,1508), September (0,1719), October (<built-in function oct>), November (0,2914), and December (0,4823). The average water scarcity level for this basin is 27,912, with 10 months of low scarcity, 1 months of moderate scarcity, 1 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 36, 'basin_name': 'Nadym'}, page_content='The basin Nadym (ID: 37) supports a population of 43644. The water scarcity levels recorded for each month are: January (0,1079), February (207,2609), March (285,6964), April (370,3467), May (0,0092), June (0,0056), July (0,0176), August (0,0283), September (0,0275), October (<built-in function oct>), November (0,0995), and December (0,1647). The average water scarcity level for this basin is 71,985, with 9 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 37, 'basin_name': 'Quoich '}, page_content='The basin Quoich  (ID: 38) supports a population of 0. The water scarcity levels recorded for each month are: January (0,0000), February (0,0000), March (0,0000), April (0,0000), May (0,0000), June (0,0000), July (0,0000), August (0,0000), September (0,0000), October (<built-in function oct>), November (0,0000), and December (0,0000). The average water scarcity level for this basin is 0,0000, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 38, 'basin_name': 'Mezen'}, page_content='The basin Mezen (ID: 39) supports a population of 42092. The water scarcity levels recorded for each month are: January (0,1069), February (8,8700), March (14,5605), April (0,0102), May (0,0038), June (0,0103), July (0,0192), August (0,0319), September (0,0499), October (<built-in function oct>), November (0,1032), and December (0,1708). The average water scarcity level for this basin is 1,9985, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 39, 'basin_name': 'Iijoki'}, page_content='The basin Iijoki (ID: 40) supports a population of 62828. The water scarcity levels recorded for each month are: January (0,7374), February (675,6757), March (675,6757), April (0,0524), May (0,0697), June (0,1756), July (0,2987), August (0,4619), September (0,4464), October (<built-in function oct>), November (0,6793), and December (1,1239). The average water scarcity level for this basin is 112,97, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 40, 'basin_name': 'Joekulsa A Fjoellum'}, page_content='The basin Joekulsa A Fjoellum (ID: 41) supports a population of 762. The water scarcity levels recorded for each month are: January (0,0150), February (675,6757), March (675,6757), April (0,1984), May (0,0015), June (0,0019), July (0,0048), August (0,0076), September (0,0077), October (<built-in function oct>), November (0,0137), and December (0,0229). The average water scarcity level for this basin is 112,64, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 41, 'basin_name': 'Svarta. Skagafiroi'}, page_content='The basin Svarta. Skagafiroi (ID: 42) supports a population of 2060. The water scarcity levels recorded for each month are: January (0,0554), February (675,6757), March (0,1037), April (0,0246), May (0,0084), June (0,0077), July (0,0206), August (0,0342), September (0,0400), October (<built-in function oct>), November (0,0442), and December (0,0845). The average water scarcity level for this basin is 56,343, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 42, 'basin_name': 'Oulujoki'}, page_content='The basin Oulujoki (ID: 43) supports a population of 196925. The water scarcity levels recorded for each month are: January (0,9418), February (194,5674), March (270,9785), April (0,0403), May (0,1309), June (0,2469), July (0,4362), August (0,7037), September (0,5771), October (<built-in function oct>), November (0,8793), and December (1,4547). The average water scarcity level for this basin is 39,272, with 10 months of low scarcity, 0 months of moderate scarcity, 1 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 43, 'basin_name': 'Lagarfljot'}, page_content='The basin Lagarfljot (ID: 44) supports a population of 3054. The water scarcity levels recorded for each month are: January (0,0400), February (675,6757), March (675,6757), April (0,2021), May (0,0038), June (0,0061), July (0,0139), August (0,0195), September (0,0175), October (<built-in function oct>), November (0,0352), and December (0,0609). The average water scarcity level for this basin is 112,65, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 44, 'basin_name': 'Thelon '}, page_content='The basin Thelon  (ID: 45) supports a population of 2168. The water scarcity levels recorded for each month are: January (0,0151), February (104,2937), March (156,8097), April (225,3312), May (0,0012), June (0,0007), July (0,0021), August (0,0036), September (0,0043), October (<built-in function oct>), November (0,0140), and December (0,0231). The average water scarcity level for this basin is 40,542, with 9 months of low scarcity, 1 months of moderate scarcity, 1 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 45, 'basin_name': 'Angerman'}, page_content='The basin Angerman (ID: 46) supports a population of 66555. The water scarcity levels recorded for each month are: January (0,1709), February (108,7415), March (162,8558), April (0,0146), May (0,0167), June (0,0219), July (0,0476), August (0,0704), September (0,0768), October (<built-in function oct>), November (0,1582), and December (0,2619). The average water scarcity level for this basin is 22,708, with 10 months of low scarcity, 1 months of moderate scarcity, 1 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 46, 'basin_name': 'Thjorsa'}, page_content='The basin Thjorsa (ID: 47) supports a population of 1985. The water scarcity levels recorded for each month are: January (0,0065), February (0,0826), March (0,0299), April (0,0024), May (0,0016), June (0,0021), July (0,0041), August (0,0047), September (0,0041), October (<built-in function oct>), November (0,0057), and December (0,0095). The average water scarcity level for this basin is 0,0130, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 47, 'basin_name': 'Northern Dvina(Severnaya Dvina)'}, page_content='The basin Northern Dvina(Severnaya Dvina) (ID: 48) supports a population of 1718380. The water scarcity levels recorded for each month are: January (1,5931), February (46,3197), March (73,3917), April (0,0365), May (0,0942), June (0,2056), July (0,3492), August (0,5502), September (0,8113), October (<built-in function oct>), November (1,6744), and December (2,7678). The average water scarcity level for this basin is 10,714, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 48, 'basin_name': 'Oelfusa'}, page_content='The basin Oelfusa (ID: 49) supports a population of 7587. The water scarcity levels recorded for each month are: January (0,0296), February (675,6757), March (0,0347), April (0,0065), May (0,0162), June (0,0163), July (0,0198), August (0,0281), September (0,0238), October (<built-in function oct>), November (0,0258), and December (0,0350). The average water scarcity level for this basin is 56,327, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 49, 'basin_name': 'Nizhny Vyg (Soroka)'}, page_content='The basin Nizhny Vyg (Soroka) (ID: 50) supports a population of 86906. The water scarcity levels recorded for each month are: January (0,3985), February (675,6757), March (675,6757), April (0,0151), May (0,0507), June (0,0888), July (0,1487), August (0,2461), September (0,1958), October (<built-in function oct>), November (0,3671), and December (0,6075). The average water scarcity level for this basin is 112,80, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 50, 'basin_name': 'Kuskokwim '}, page_content='The basin Kuskokwim  (ID: 51) supports a population of 11404. The water scarcity levels recorded for each month are: January (0,0227), February (20,4901), March (33,2636), April (53,3575), May (0,0018), June (0,0037), July (0,0053), August (0,0053), September (0,0054), October (<built-in function oct>), November (0,0210), and December (0,0347). The average water scarcity level for this basin is 8,9353, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 51, 'basin_name': 'Vuoksi'}, page_content='The basin Vuoksi (ID: 52) supports a population of 750077. The water scarcity levels recorded for each month are: January (2,4651), February (675,6757), March (675,6757), April (0,0784), May (0,2890), June (0,5207), July (0,9400), August (1,6671), September (1,6837), October (<built-in function oct>), November (2,1329), and December (3,7524). The average water scarcity level for this basin is 113,8124, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 52, 'basin_name': 'Onega'}, page_content='The basin Onega (ID: 53) supports a population of 176080. The water scarcity levels recorded for each month are: January (0,7413), February (59,1222), March (92,5763), April (0,0157), May (0,0561), June (0,1120), July (0,1881), August (0,2819), September (0,3877), October (<built-in function oct>), November (0,7102), and December (1,1819). The average water scarcity level for this basin is 12,9728, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 53, 'basin_name': 'Susitna '}, page_content='The basin Susitna  (ID: 54) supports a population of 30093. The water scarcity levels recorded for each month are: January (0,0600), February (34,0115), March (54,5130), April (0,0210), May (0,0113), June (0,0107), July (0,0156), August (0,0188), September (0,0158), October (<built-in function oct>), November (0,0557), and December (0,0921). The average water scarcity level for this basin is 7,4044, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 54, 'basin_name': 'Kymijoki'}, page_content='The basin Kymijoki (ID: 55) supports a population of 587655. The water scarcity levels recorded for each month are: January (3,4503), February (675,6757), March (675,6757), April (0,1406), May (0,5170), June (0,9373), July (1,6307), August (2,9313), September (3,3671), October (<built-in function oct>), November (2,0639), and December (5,2481). The average water scarcity level for this basin is 114,4784, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 55, 'basin_name': 'Neva'}, page_content='The basin Neva (ID: 56) supports a population of 4244810. The water scarcity levels recorded for each month are: January (3,3585), February (378,5483), March (458,3735), April (0,1251), May (0,5531), June (1,1039), July (1,6824), August (2,9494), September (2,6044), October (<built-in function oct>), November (2,3799), and December (5,1865). The average water scarcity level for this basin is 71,5348, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 56, 'basin_name': 'Ferguson '}, page_content='The basin Ferguson  (ID: 57) supports a population of 7. The water scarcity levels recorded for each month are: January (0,0006), February (675,6757), March (675,6757), April (675,6757), May (675,6757), June (0,0000), July (0,0001), August (0,0001), September (0,0002), October (<built-in function oct>), November (0,0005), and December (0,0008). The average water scarcity level for this basin is 225,2254, with 8 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 4 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 57, 'basin_name': 'Copper'}, page_content='The basin Copper (ID: 58) supports a population of 4949. The water scarcity levels recorded for each month are: January (0,0114), February (675,6757), March (675,6757), April (0,7201), May (0,0017), June (0,0012), July (0,0017), August (0,0030), September (0,0031), October (<built-in function oct>), November (0,0105), and December (0,0174). The average water scarcity level for this basin is 112,6773, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 58, 'basin_name': 'Gloma'}, page_content='The basin Gloma (ID: 59) supports a population of 759489. The water scarcity levels recorded for each month are: January (1,5345), February (675,6757), March (72,0236), April (0,2514), May (0,2825), June (0,4131), July (1,0384), August (1,5595), September (0,7779), October (<built-in function oct>), November (1,2754), and December (2,3375). The average water scarcity level for this basin is 63,1510, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 59, 'basin_name': 'Kokemaenjoki'}, page_content='The basin Kokemaenjoki (ID: 60) supports a population of 773376. The water scarcity levels recorded for each month are: January (3,6118), February (531,9680), March (580,8959), April (0,2335), May (0,8757), June (1,6857), July (3,0361), August (5,7593), September (7,2883), October (<built-in function oct>), November (1,7038), and December (5,5237). The average water scarcity level for this basin is 95,6848, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 60, 'basin_name': 'Vaenern-Goeta'}, page_content='The basin Vaenern-Goeta (ID: 61) supports a population of 1485740. The water scarcity levels recorded for each month are: January (1,1060), February (407,7808), March (0,5864), April (0,2466), May (0,6221), June (1,1629), July (2,1068), August (2,2544), September (1,7350), October (<built-in function oct>), November (0,8196), and December (1,2777). The average water scarcity level for this basin is 35,0497, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 61, 'basin_name': 'Thlewiaza '}, page_content='The basin Thlewiaza  (ID: 62) supports a population of 52. The water scarcity levels recorded for each month are: January (0,0019), February (0,0168), March (0,0279), April (0,0462), May (0,0001), June (0,0003), July (0,0005), August (0,0008), September (0,0009), October (<built-in function oct>), November (0,0030), and December (0,0050). The average water scarcity level for this basin is 0,0088, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 62, 'basin_name': 'Alsek'}, page_content='The basin Alsek (ID: 63) supports a population of 1032. The water scarcity levels recorded for each month are: January (0,0115), February (675,6757), March (675,6757), April (0,0056), May (0,0013), June (0,0012), July (0,0030), August (0,0045), September (0,0034), October (<built-in function oct>), November (0,0106), and December (0,0175). The average water scarcity level for this basin is 112,6179, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 63, 'basin_name': 'Volga'}, page_content='The basin Volga (ID: 64) supports a population of 61273800. The water scarcity levels recorded for each month are: January (18,7675), February (394,2596), March (77,6644), April (0,5405), May (5,9489), June (13,9749), July (32,6405), August (44,8040), September (25,8475), October (<built-in function oct>), November (19,0591), and December (30,5202). The average water scarcity level for this basin is 56,3824, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 64, 'basin_name': 'Dramselv'}, page_content='The basin Dramselv (ID: 65) supports a population of 282181. The water scarcity levels recorded for each month are: January (1,2364), February (675,6757), March (3,3103), April (0,2605), May (0,2243), June (0,2948), July (0,7559), August (0,6801), September (0,4876), October (<built-in function oct>), November (1,0535), and December (1,8838). The average water scarcity level for this basin is 57,1975, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 65, 'basin_name': 'Arnaud'}, page_content='The basin Arnaud (ID: 66) supports a population of 0. The water scarcity levels recorded for each month are: January (0,0000), February (0,0000), March (0,0000), April (0,0000), May (0,0000), June (0,0000), July (0,0000), August (0,0000), September (0,0000), October (<built-in function oct>), November (0,0000), and December (0,0000). The average water scarcity level for this basin is 0,0000, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 66, 'basin_name': 'Nushagak '}, page_content='The basin Nushagak  (ID: 67) supports a population of 1469. The water scarcity levels recorded for each month are: January (0,0072), February (675,6757), March (675,6757), April (0,0028), May (0,0008), June (0,0021), July (0,0036), August (0,0029), September (0,0024), October (<built-in function oct>), November (0,0066), and December (0,0110). The average water scarcity level for this basin is 112,6161, with 10 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
# ...
#  Document(metadata={'index': 384, 'basin_name': 'Sungai Mahakam'}, page_content='The basin Sungai Mahakam (ID: 385) supports a population of 891886. The water scarcity levels recorded for each month are: January (0,0431), February (0,0521), March (0,0142), April (0,0097), May (0,0117), June (0,0144), July (0,0369), August (0,0538), September (0,2843), October (<built-in function oct>), November (0,0606), and December (0,0393). The average water scarcity level for this basin is 0,0644, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 385, 'basin_name': 'Sungai Kapuas'}, page_content='The basin Sungai Kapuas (ID: 386) supports a population of 1606700. The water scarcity levels recorded for each month are: January (0,0191), February (0,0289), March (0,0162), April (0,0147), May (0,0171), June (0,0227), July (0,0340), August (0,0372), September (0,0618), October (<built-in function oct>), November (0,0187), and December (0,0186). The average water scarcity level for this basin is 0,0263, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 386, 'basin_name': 'Batang Kuantan'}, page_content='The basin Batang Kuantan (ID: 387) supports a population of 1519730. The water scarcity levels recorded for each month are: January (2,8211), February (3,0608), March (0,2400), April (0,2084), May (0,3146), June (1,0426), July (2,3173), August (2,9105), September (9,9064), October (<built-in function oct>), November (2,7841), and December (1,9424). The average water scarcity level for this basin is 2,7208, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 387, 'basin_name': 'Batang Hari'}, page_content='The basin Batang Hari (ID: 388) supports a population of 2049480. The water scarcity levels recorded for each month are: January (0,8612), February (0,9287), March (0,0969), April (0,0792), May (0,1676), June (0,4931), July (0,9628), August (1,4025), September (3,6364), October (<built-in function oct>), November (1,0064), and December (0,6505). The average water scarcity level for this basin is 1,0258, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 388, 'basin_name': 'Flinders '}, page_content='The basin Flinders  (ID: 389) supports a population of 6334. The water scarcity levels recorded for each month are: January (16,4188), February (0,1479), March (2,3064), April (6,2021), May (9,3989), June (12,8657), July (23,1964), August (45,3361), September (83,9322), October (<built-in function oct>), November (149,4369), and December (159,4244). The average water scarcity level for this basin is 53,1311, with 9 months of low scarcity, 2 months of moderate scarcity, 1 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 389, 'basin_name': 'Leichhardt '}, page_content='The basin Leichhardt  (ID: 390) supports a population of 6430. The water scarcity levels recorded for each month are: January (0,2065), February (0,1982), March (1,0076), April (2,2161), May (3,5819), June (5,3255), July (9,2949), August (17,1238), September (30,4700), October (<built-in function oct>), November (63,4573), and December (76,7928). The average water scarcity level for this basin is 21,5208, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 390, 'basin_name': 'Escaut (Schelde)'}, page_content='The basin Escaut (Schelde) (ID: 391) supports a population of 9448070. The water scarcity levels recorded for each month are: January (10,5740), February (20,2440), March (23,6613), April (30,4949), May (56,0009), June (99,7116), July (163,8537), August (244,0545), September (292,3902), October (<built-in function oct>), November (38,2835), and December (19,1539). The average water scarcity level for this basin is 102,1553, with 8 months of low scarcity, 0 months of moderate scarcity, 1 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 391, 'basin_name': 'Issyk-Kul'}, page_content='The basin Issyk-Kul (ID: 392) supports a population of 3325290. The water scarcity levels recorded for each month are: January (6,4377), February (39,8246), March (1,3156), April (12,5627), May (38,5639), June (69,1434), July (108,5862), August (204,1123), September (227,2760), October (<built-in function oct>), November (31,0648), and December (11,4322). The average water scarcity level for this basin is 76,3089, with 8 months of low scarcity, 1 months of moderate scarcity, 1 months of significant scarcity, and 2 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 392, 'basin_name': 'Balkhash'}, page_content='The basin Balkhash (ID: 393) supports a population of 5182190. The water scarcity levels recorded for each month are: January (14,4406), February (675,6757), March (6,0052), April (21,7479), May (44,9506), June (77,6184), July (157,1146), August (261,8551), September (300,4459), October (<built-in function oct>), November (17,4527), and December (23,2170). The average water scarcity level for this basin is 148,3695, with 7 months of low scarcity, 0 months of moderate scarcity, 2 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 393, 'basin_name': 'Eyre Lake'}, page_content='The basin Eyre Lake (ID: 394) supports a population of 86249. The water scarcity levels recorded for each month are: January (674,3073), February (674,7129), March (675,4052), April (675,5506), May (675,6234), June (675,6234), July (675,6616), August (675,6513), September (675,6459), October (<built-in function oct>), November (675,5155), and December (675,3102). The average water scarcity level for this basin is 675,3861, with 0 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 12 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 394, 'basin_name': 'Lake Mar Chiquita'}, page_content='The basin Lake Mar Chiquita (ID: 395) supports a population of 4096920. The water scarcity levels recorded for each month are: January (75,0833), February (61,2397), March (24,5206), April (42,4430), May (41,9168), June (74,2884), July (154,8408), August (268,7374), September (410,8614), October (<built-in function oct>), November (235,4769), and December (112,5411). The average water scarcity level for this basin is 152,1664, with 6 months of low scarcity, 1 months of moderate scarcity, 1 months of significant scarcity, and 4 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 395, 'basin_name': 'Lake Turkana'}, page_content='The basin Lake Turkana (ID: 396) supports a population of 8701300. The water scarcity levels recorded for each month are: January (4,0102), February (675,6729), March (34,6764), April (0,5005), May (0,3998), June (0,2868), July (0,2343), August (0,4719), September (0,6393), October (<built-in function oct>), November (0,9919), and December (3,0301). The average water scarcity level for this basin is 60,1397, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 396, 'basin_name': 'Dead Sea'}, page_content='The basin Dead Sea (ID: 397) supports a population of 6149610. The water scarcity levels recorded for each month are: January (4,1131), February (7,7788), March (51,5262), April (214,3257), May (371,6238), June (444,3434), July (531,1691), August (573,7264), September (568,3607), October (<built-in function oct>), November (531,6836), and December (68,5694). The average water scarcity level for this basin is 328,0037, with 4 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 8 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 397, 'basin_name': 'Suriname'}, page_content='The basin Suriname (ID: 398) supports a population of 102802. The water scarcity levels recorded for each month are: January (0,0166), February (0,0190), March (0,0174), April (0,0125), May (0,0077), June (0,0073), July (0,0092), August (0,0150), September (0,0300), October (<built-in function oct>), November (0,0826), and December (0,0691). The average water scarcity level for this basin is 0,0280, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 398, 'basin_name': 'Lake Titicaca'}, page_content='The basin Lake Titicaca (ID: 399) supports a population of 2690710. The water scarcity levels recorded for each month are: January (3,8339), February (3,3416), March (3,0617), April (4,2793), May (4,7054), June (7,1890), July (9,4926), August (14,4444), September (18,3273), October (<built-in function oct>), November (15,3962), and December (5,8656). The average water scarcity level for this basin is 8,6187, with 12 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 0 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 399, 'basin_name': 'Lake Vattern'}, page_content='The basin Lake Vattern (ID: 400) supports a population of 405048. The water scarcity levels recorded for each month are: January (3,2906), February (675,6757), March (0,5556), April (0,6713), May (1,7349), June (3,6514), July (7,3175), August (11,3250), September (11,8803), October (<built-in function oct>), November (1,8303), and December (4,1894). The average water scarcity level for this basin is 60,5438, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 400, 'basin_name': 'Great Salt Lake'}, page_content='The basin Great Salt Lake (ID: 401) supports a population of 2224190. The water scarcity levels recorded for each month are: January (86,3922), February (23,8773), March (37,9263), April (69,3490), May (103,8457), June (229,3599), July (368,6795), August (422,2226), September (417,9784), October (<built-in function oct>), November (235,0614), and December (99,9358). The average water scarcity level for this basin is 208,6308, with 5 months of low scarcity, 1 months of moderate scarcity, 0 months of significant scarcity, and 6 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 401, 'basin_name': 'Lake Taymur'}, page_content='The basin Lake Taymur (ID: 402) supports a population of 6188. The water scarcity levels recorded for each month are: January (0,0081), February (157,0790), March (225,6940), April (306,5597), May (391,1833), June (0,0004), July (0,0009), August (0,0018), September (0,0023), October (<built-in function oct>), November (0,0075), and December (0,0124). The average water scarcity level for this basin is 90,0462, with 8 months of low scarcity, 0 months of moderate scarcity, 1 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 402, 'basin_name': 'Daryacheh-Ye Orumieh'}, page_content='The basin Daryacheh-Ye Orumieh (ID: 403) supports a population of 4306830. The water scarcity levels recorded for each month are: January (13,2194), February (37,5978), March (33,2275), April (27,3501), May (32,7817), June (90,7096), July (172,8032), August (266,8108), September (271,1349), October (<built-in function oct>), November (65,4205), and December (32,5219). The average water scarcity level for this basin is 104,1694, with 8 months of low scarcity, 0 months of moderate scarcity, 1 months of significant scarcity, and 3 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 403, 'basin_name': 'Van Golu'}, page_content='The basin Van Golu (ID: 404) supports a population of 893956. The water scarcity levels recorded for each month are: January (3,5935), February (675,6757), March (3,9109), April (0,8077), May (3,1849), June (18,9333), July (29,9880), August (51,1923), September (59,5154), October (<built-in function oct>), November (3,5220), and December (6,1803). The average water scarcity level for this basin is 73,0456, with 11 months of low scarcity, 0 months of moderate scarcity, 0 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. '),
#  Document(metadata={'index': 404, 'basin_name': 'Ozero Sevan'}, page_content='The basin Ozero Sevan (ID: 405) supports a population of 412357. The water scarcity levels recorded for each month are: January (58,7163), February (675,6757), March (143,7254), April (7,7445), May (8,3609), June (41,9546), July (105,3181), August (174,5054), September (159,6708), October (<built-in function oct>), November (40,2273), and December (88,2488). The average water scarcity level for this basin is 131,9251, with 7 months of low scarcity, 2 months of moderate scarcity, 2 months of significant scarcity, and 1 months of severe scarcity. This data provides a comprehensive understanding of water scarcity throughout the year for the region. ')]

# %%
print(water_data.columns)
# Out:
# Index(['basin_id', 'basin_name', 'population', 'jan', 'feb', 'mar', 'apr',
#        'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec', 'average',
#        'low', 'moderate', 'significant', 'severe'],
#       dtype='object')

# %%
import pandas as pd
from langchain.schema import Document

# Load the CSV file
csv_file_path = "data/csv/global_water_consumption.csv"
water_data = pd.read_csv(csv_file_path)


def load_water_usage_data():
    # Process the data and fill in placeholders
    documents = []
    for index, row in water_data.iterrows():
        # Extract all the columns from the current row
        country = row['Country']
        year = row['Year']
        total_water_consumption = row['Total Water Consumption (Billion Cubic Meters)']
        per_capital_use = row['Per Capita Water Use (Liters per Day)']
        agricultural_use = row['Agricultural Water Use (%)']
        industrial_use = row['Industrial Water Use (%)']
        household_use = row['Household Water Use (%)']
        rainfall = row['Rainfall Impact (Annual Precipitation in mm)']
        groundwater_depletion = row['Groundwater Depletion Rate (%)']
        scarcity_level = row['Water Scarcity Level']
        content = f"The country {country} reported water consumption statistics for the year {year}. The total water consumption was {total_water_consumption} billion cubic meters, with a per capita water consumption of {per_capital_use} liters per day. Water distribution included {agricultural_use}% for agricultural use, {industrial_use}% for industrial use, and {household_use}% for household use. The region experienced an annual rainfall impact of {rainfall} mm, while the groundwater depletion rate was recorded at {groundwater_depletion}%. Based on these figures, the water scarcity level in {year} was categorized as {scarcity_level}. "
        documents.append(Document(page_content=content, metadata={"index": index, "country": country, "year": year}))
    return documents


global_water_consumption_csv = load_water_usage_data()
global_water_consumption_csv
# Out:
# [Document(metadata={'index': 0, 'country': 'Argentina', 'year': 2000}, page_content='The country Argentina reported water consumption statistics for the year 2000. The total water consumption was 481.49 billion cubic meters, with a per capita water consumption of 235.4314286 liters per day. Water distribution included 48.55% for agricultural use, 20.84428571% for industrial use, and 30.1% for household use. The region experienced an annual rainfall impact of 1288.698571 mm, while the groundwater depletion rate was recorded at 3.255714286%. Based on these figures, the water scarcity level in 2000 was categorized as Moderate. '),
#  Document(metadata={'index': 1, 'country': 'Argentina', 'year': 2001}, page_content='The country Argentina reported water consumption statistics for the year 2001. The total water consumption was 455.063 billion cubic meters, with a per capita water consumption of 299.551 liters per day. Water distribution included 48.465% for agricultural use, 26.943% for industrial use, and 22.55% for household use. The region experienced an annual rainfall impact of 1371.729 mm, while the groundwater depletion rate was recorded at 3.12%. Based on these figures, the water scarcity level in 2001 was categorized as Moderate. '),
#  Document(metadata={'index': 2, 'country': 'Argentina', 'year': 2002}, page_content='The country Argentina reported water consumption statistics for the year 2002. The total water consumption was 482.7492308 billion cubic meters, with a per capita water consumption of 340.1246154 liters per day. Water distribution included 50.37538462% for agricultural use, 29.04230769% for industrial use, and 23.34923077% for household use. The region experienced an annual rainfall impact of 1590.305385 mm, while the groundwater depletion rate was recorded at 2.733846154%. Based on these figures, the water scarcity level in 2002 was categorized as Moderate. '),
#  Document(metadata={'index': 3, 'country': 'Argentina', 'year': 2003}, page_content='The country Argentina reported water consumption statistics for the year 2003. The total water consumption was 452.66 billion cubic meters, with a per capita water consumption of 326.7566667 liters per day. Water distribution included 49.08666667% for agricultural use, 30.476% for industrial use, and 24.44% for household use. The region experienced an annual rainfall impact of 1816.012667 mm, while the groundwater depletion rate was recorded at 2.708%. Based on these figures, the water scarcity level in 2003 was categorized as Moderate. '),
#  Document(metadata={'index': 4, 'country': 'Argentina', 'year': 2004}, page_content='The country Argentina reported water consumption statistics for the year 2004. The total water consumption was 634.566 billion cubic meters, with a per capita water consumption of 230.346 liters per day. Water distribution included 38.67% for agricultural use, 36.67% for industrial use, and 23.924% for household use. The region experienced an annual rainfall impact of 815.998 mm, while the groundwater depletion rate was recorded at 1.902%. Based on these figures, the water scarcity level in 2004 was categorized as Moderate. '),
#  Document(metadata={'index': 494, 'country': 'USA', 'year': 2019}, page_content='The country USA reported water consumption statistics for the year 2019. The total water consumption was 547.864375 billion cubic meters, with a per capita water consumption of 283.96875 liters per day. Water distribution included 46.826875% for agricultural use, 25.886875% for industrial use, and 22.58% for household use. The region experienced an annual rainfall impact of 1461.96625 mm, while the groundwater depletion rate was recorded at 2.825%. Based on these figures, the water scarcity level in 2019 was categorized as Moderate. '),
#  Document(metadata={'index': 495, 'country': 'USA', 'year': 2020}, page_content='The country USA reported water consumption statistics for the year 2020. The total water consumption was 418.097 billion cubic meters, with a per capita water consumption of 292.97 liters per day. Water distribution included 47.448% for agricultural use, 25.266% for industrial use, and 27.538% for household use. The region experienced an annual rainfall impact of 1510.662 mm, while the groundwater depletion rate was recorded at 2.431%. Based on these figures, the water scarcity level in 2020 was categorized as Moderate. '),
#  Document(metadata={'index': 496, 'country': 'USA', 'year': 2021}, page_content='The country USA reported water consumption statistics for the year 2021. The total water consumption was 572.094 billion cubic meters, with a per capita water consumption of 275.978 liters per day. Water distribution included 46.195% for agricultural use, 32.223% for industrial use, and 26.72% for household use. The region experienced an annual rainfall impact of 754.615 mm, while the groundwater depletion rate was recorded at 2.628%. Based on these figures, the water scarcity level in 2021 was categorized as Moderate. '),
#  Document(metadata={'index': 497, 'country': 'USA', 'year': 2022}, page_content='The country USA reported water consumption statistics for the year 2022. The total water consumption was 440.978 billion cubic meters, with a per capita water consumption of 292.039 liters per day. Water distribution included 54.81% for agricultural use, 30.918% for industrial use, and 22.638% for household use. The region experienced an annual rainfall impact of 2119.898 mm, while the groundwater depletion rate was recorded at 2.871%. Based on these figures, the water scarcity level in 2022 was categorized as Moderate. '),
#  Document(metadata={'index': 498, 'country': 'USA', 'year': 2023}, page_content='The country USA reported water consumption statistics for the year 2023. The total water consumption was 566.865 billion cubic meters, with a per capita water consumption of 261.1975 liters per day. Water distribution included 62.945% for agricultural use, 25.2075% for industrial use, and 21.6325% for household use. The region experienced an annual rainfall impact of 1439.155 mm, while the groundwater depletion rate was recorded at 1.5975%. Based on these figures, the water scarcity level in 2023 was categorized as Moderate. '),
#  Document(metadata={'index': 499, 'country': 'USA', 'year': 2024}, page_content='The country USA reported water consumption statistics for the year 2024. The total water consumption was 249.485 billion cubic meters, with a per capita water consumption of 186.374 liters per day. Water distribution included 51.386% for agricultural use, 24.769% for industrial use, and 27.677% for household use. The region experienced an annual rainfall impact of 1771.199 mm, while the groundwater depletion rate was recorded at 1.638%. Based on these figures, the water scarcity level in 2024 was categorized as High. ')]

# %%
#create vectorstore with chroma to store the documents
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings


def create_vectorstore(docs, persist_dir="./chroma_db"):
    embeddings = OpenAIEmbeddings()
    vectordb = Chroma.from_documents(docs, embeddings, persist_directory=persist_dir)
    return vectordb

pdf_csv_docs = water_usage_csv + water_scarcity_csv + global_water_consumption_csv + pdf_chunks
db = create_vectorstore(pdf_csv_docs)
# Out:
# C:\Users\MediaMonster\AppData\Local\Temp\ipykernel_7796\249856146.py:7: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()

# %%
result = db.similarity_search(
    'availability of water in jaipur',
    k=6  #6 nearest neighbors
)
print(f"for query {len(result)} results found")
print(result[0].page_content)
print(result[0].metadata)
# Out:
# for query 6 results found
# In the district Jaipur, the crop Barley is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 8087.602263601358, while the water availability in the region is around 8487.71266227881. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.
# {'index': 435}

# %%
#prompt engineering
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# Define the system message template (sets the AI's behavior and context)
system_message = SystemMessagePromptTemplate.from_template("""
You are a helpful assistant specialized in water usage, irrigation techniques, soil analysis, and water scarcity data.
Your job is to analyze relevant material provided in the context and answer user queries accurately.
Always use the context provided to create factual responses.
""")

# Define the human message template (includes user query and context dynamically)
human_message = HumanMessagePromptTemplate.from_template("""
Context:
{context}

Question:
{question}

Provide a detailed and accurate response based on the context above. If the context does not contain enough information, say so and avoid guessing.
""")

# Combine the templates into a ChatPromptTemplate
chat_prompt = ChatPromptTemplate.from_messages([system_message, human_message])
# Define inputs
retrieved_context = [doc.page_content for doc in db.similarity_search('availability of water in jaipur', k=6)]
user_query = "what are the major water-related disasters ?"

# Render the chat prompt with actual inputs
formatted_prompt = chat_prompt.format_prompt(
    context=" ".join(retrieved_context),
    question=user_query
)

# %%
from langchain.prompts import PromptTemplate, MessagesPlaceholder
from langchain.prompts.chat import SystemMessagePromptTemplate, HumanMessagePromptTemplate

qa_system_prompt_template = """
You are a chatbot specialized in water scarcity and related challenges around the globe. Your job is to assist researchers, NGOs, and policymakers in exploring data, solutions, and impacts regarding water scarcity. Use the provided information to answer questions accurately and reliably. If you don't know the answer based on the context, say you don't know. Follow these rules:

1. If the question is to request links, please only return the source links with no answer.
2. If you don't know the answer, don't fabricate a response. Just say **I can't find the final answer but you may want to check the following links** and add the source links as a list.
3. If you find the answer, write the answer in a concise way and add the list of sources that are **directly** used to derive the answer. Exclude the sources that are irrelevant to the final answer.

{context}"""

qa_system_prompt = SystemMessagePromptTemplate(
    prompt=PromptTemplate(
        input_variables=["context"], template=qa_system_prompt_template
    )
)

qa_human_prompt_template = """Question: {input}
Answer:"""

qa_human_prompt = HumanMessagePromptTemplate(
    prompt=PromptTemplate(input_variables=["question"], template=qa_human_prompt_template)
)

qa_prompt = ChatPromptTemplate.from_messages(
    [
        qa_system_prompt,
        MessagesPlaceholder("chat_history"),
        qa_human_prompt,
    ]
)

# %%
#dynamic prompt setup
from openai import ChatCompletion
import json

# formatted_prompt = [
#      {"role": "system", "content": "You are a helpful assistant specialized in water usage, irrigation techniques, soil analysis, and water scarcity data. Your job is to analyze relevant material provided in the context and answer user queries accurately. Always use the context provided to create factual responses."},
#      {"role": "user", "content": "What is the capital of France?"}
#  ]
prompt = formatted_prompt
model_gen = ChatCompletion.create

# %%
print(type(formatted_prompt))
print(formatted_prompt)
# Out:
# <class 'langchain_core.prompt_values.ChatPromptValue'>
# messages=[SystemMessage(content='\nYou are a helpful assistant specialized in water usage, irrigation techniques, soil analysis, and water scarcity data.\nYour job is to analyze relevant material provided in the context and answer user queries accurately.\nAlways use the context provided to create factual responses.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='\nContext:\nIn the district Jaipur, the crop Barley is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 8087.602263601358, while the water availability in the region is around 8487.71266227881. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system. In the district Jaipur, the crop Barley is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 8300.162932253157, while the water availability in the region is around 8995.547221478551. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system. In the district Jaipur, the crop Barley is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12240.947529657356, while the water availability in the region is around 11467.276268887224. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system. In the district Jaipur, the crop Maize is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 15820.68530880267, while the water availability in the region is around 14899.188553287644. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system. In the district Jaipur, the crop Maize is cultivated using the Tube Well method. The water consumption for this irrigation method is approximately 12260.0572581808, while the water availability in the region is around 12048.593905518686. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system. In the district Jaipur, the crop Bajra is cultivated using the Sprinkler Irrigation method. The water consumption for this irrigation method is approximately 13314.374907775818, while the water availability in the region is around 13218.535047681751. This indicates a relatively high water requirement for guava cultivation,which is supported by adequate water availability in the region through the canal irrigation system.\n\nQuestion:\nwhat are the major water-related disasters ?\n\nProvide a detailed and accurate response based on the context above. If the context does not contain enough information, say so and avoid guessing.\n', additional_kwargs={}, response_metadata={})]

# %%
#convert prompts to message format
def to_messages(prompt_list):
    return [{"role": "user", "content": message} for message in prompt_list]

# Pass the rendered prompt to your LLM
response = model_gen(
    model="gpt-4",
    messages= formatted_prompt
    # messages= formatted_prompt
)
print(response.choices[0].message["content"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 6
#       3     return [{"role": "user", "content": message} for message in prompt_list]
#       5 # Pass the rendered prompt to your LLM
# ----> 6 response = model_gen(
#       7     model="gpt-4",
#       8     messages= formatted_prompt
#       9     # messages= formatted_prompt
#      10 )
#      11 print(response.choices[0].message["content"])
#
# File ~\Desktop\MASTER\MA2\AI_Ma2\Pjt_AI_Water_NGOs\.venv\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~\Desktop\MASTER\MA2\AI_Ma2\Pjt_AI_Water_NGOs\.venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)    136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)    150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~\Desktop\MASTER\MA2\AI_Ma2\Pjt_AI_Water_NGOs\.venv\Lib\site-packages\openai\api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)    286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~\Desktop\MASTER\MA2\AI_Ma2\Pjt_AI_Water_NGOs\.venv\Lib\site-packages\openai\api_requestor.py:581, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     569 def request_raw(
#     570     self,
#     571     method,
#    (...)    579     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     580 ) -> requests.Response:
# --> 581     abs_url, headers, data = self._prepare_request_raw(
#     582         url, supplied_headers, method, params, files, request_id
#     583     )
#     585     if not hasattr(_thread_context, "session"):
#     586         _thread_context.session = _make_session()
#
# File ~\Desktop\MASTER\MA2\AI_Ma2\Pjt_AI_Water_NGOs\.venv\Lib\site-packages\openai\api_requestor.py:553, in APIRequestor._prepare_request_raw(self, url, supplied_headers, method, params, files, request_id)
#     551         data = params
#     552     if params and not files:
# --> 553         data = json.dumps(params).encode()
#     554         headers["Content-Type"] = "application/json"
#     555 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type ChatPromptValue is not JSON serializable
